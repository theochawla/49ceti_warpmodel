# %%
import disk_ecc as original
import disk_ecc_warp_setstructure as mine

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
# %run raytrace_3dwarp.py
x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20, w_pos=40)
# Out:
# zcf max 448793612100000.0
# zcf min -448793612100000.0
# dz max 718644695116.125
# dz min -897587224200000.0
# dz shape (500, 131, 1250)
# Beware: removed NaNs from density (#74932)
# zpht shape (500, 131)
# temp_interp shape (500, 131, 1250)
# p_w shape (500, 131, 1250)
# tdiskZ min -1.7900081661001806e+16
# tdiskZ max 1.7900081661001806e+16
# zpht_vals shape: (81875000,)
# pts shape: (81875000, 3)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().run_line_magic('run', 'raytrace_3dwarp.py')
# ----> 2 x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20, w_pos=40)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_last_ditch/disk_ecc_warp_setstructure.py:289, in Disk.__init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring, w_i, w_r0, w_dr, w_pa, w_pos)
#     287 self.set_structure()  # use obs and params to create disk structure
#     288 if rtg:
# --> 289     self.set_rt_grid()
#     290     self.set_line(line=line,vcs=vcs)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_last_ditch/disk_ecc_warp_setstructure.py:1285, in set_rt_grid(self)
#    1257 #tT = ndimage.map_coordinates(self.tempg,[[aind],[phiind],[zind]],order=1,cval=1e-18).reshape(self.nphi,self.nr,self.nz)
#    1258 '''
#    1259 temp_interp = interpnd((self.r_w.flatten(), self.p_w.flatten(), self.z_w.flatten()), self.tempg.flatten())
#    1260 sig_col_interp = interpnd((self.r_w.flatten(), self.p_w.flatten(), self.z_w.flatten()), self.sig_col.flatten())
#    (...)
#    1270 rho0 = rho0_interp((tr.flatten(), tphi.flatten(), tdiskZ.flatten())).reshape(tr.shape)
#    1271 '''
#    1273 '''
#    1274 # build scattered point cloud in warped coordinates
#    1275 pts = np.vstack([self.r_w.ravel(), self.p_w.ravel(), self.z_w.ravel()]).T
#    1276 temp_vals = self.tempg.ravel()
#    1277 sig_vals = self.sig_col.ravel()
#    1278 vel_vals = self.vel.ravel()
#    1279 rho_vals = self.rho0.ravel()
#    1280
#    1281 # optionally choose a kernel and neighbors to reduce smoothing/compute
#    1282 temp_interp = RBFInterpolator(pts, temp_vals, kernel='linear', neighbors=32)
#    1283 sig_col_interp = RBFInterpolator(pts, sig_vals, kernel='linear', neighbors=32)
#    1284 vel_interp = RBFInterpolator(pts, vel_vals, kernel='linear', neighbors=32)
# -> 1285 rho0_interp = RBFInterpolator(pts, rho_vals, kernel='linear', neighbors=32)
#    1286
#    1287 # zpht is 2D in (r_w,p_w), so use 2D points
#    1288 #pts2 = np.vstack([self.r_w[:,:,0].ravel(), self.p_w[:,:,0].ravel()]).T
#    1289 #print(f"pts2 shape: {pts2.shape}")
#    1290 zpht_vals = self.zpht_up.ravel()
#    1291 print(f"zpht_vals shape: {zpht_vals.shape}")
#    1292 print(f"pts shape: {pts.shape}")
#    1293 zpht_interp = RBFInterpolator(pts, zpht_vals, kernel='linear', neighbors=32)
#    1294
#    1295 # query points
#    1296 q = np.vstack([tr.ravel(), tphi.ravel(), tdiskZ.ravel()]).T
#    1297 tT = temp_interp(q).reshape(tr.shape)
#    1298 tvel = vel_interp(q).reshape(tr.shape)
#    1299 tsig_col = sig_col_interp(q).reshape(tr.shape)
#    1300 rho0 = rho0_interp(q).reshape(tr.shape)
#    1301
#    1302 q2 = np.vstack([tr.ravel(), tphi.ravel()]).T
#    1303 zpht_up = zpht_interp(q2).reshape(tr.shape)
#    1304 #self.nphi,self.nr,self.nz
#    1305 '''
#    1307 z_w_max = np.max(tdiskZ)
#    1308 self.z_w_max = z_w_max
#
# File /opt/anaconda3_roy/lib/python3.11/site-packages/scipy/interpolate/_rbfinterp.py:530, in RBFInterpolator.__call__(self, x)
#     528         dnbr = self.d[yidx]
#     529         snbr = self.smoothing[yidx]
# --> 530         shift, scale, coeffs = _build_and_solve_system(
#     531             ynbr,
#     532             dnbr,
#     533             snbr,
#     534             self.kernel,
#     535             self.epsilon,
#     536             self.powers,
#     537         )
#     538         out[xidx] = self._chunk_evaluator(
#     539             xnbr,
#     540             ynbr,
#    (...)
#     543             coeffs,
#     544             memory_budget=memory_budget)
#     546 out = out.view(self.d_dtype)
#
# File /opt/anaconda3_roy/lib/python3.11/site-packages/scipy/interpolate/_rbfinterp.py:129, in _build_and_solve_system(y, d, smoothing, kernel, epsilon, powers)
#     122         if rank < nmonos:
#     123             msg = (
#     124                 "Singular matrix. The matrix of monomials evaluated at "
#     125                 "the data point coordinates does not have full column "
#     126                 f"rank ({rank}/{nmonos})."
#     127                 )
# --> 129     raise LinAlgError(msg)
#     131 return shift, scale, coeffs
#
# LinAlgError: Singular matrix.

# %%
# %run raytrace_3dwarp.py

# %%
81875000/131
# Out:
# 625000.0

# %%
total_model(x,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

# %%
import disk_ecc as original
#import disk_ecc_warp_backto_setstructure as mine
import disk_ecc_warp_setstructure_original as mine
import disk_ecc_warp_setstructure_lasttry as lasttry

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
#x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=60, w_i=5, w_r0=150,w_dr=40,w_pa=45, w_pos=0)
#z=original.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=80)

# %%
#x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=60, w_i=5, w_r0=150,w_dr=40,w_pa=45, w_pos=0)
x=lasttry.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=1, w_i=0, w_r0=150,w_dr=40,w_pa=0, Ain=20)
# Out:
# zcf max 448793612100000.0
# zcf min 1495978707000.0
# dz max 358124606399.5625
# dz min -447297633393000.0
# dz shape (500, 131, 1250)
# X_0 0.0
# X_-1 8975872242000000.0
# Y_0 0.0
# Y_-1 0.0
# X shape (131, 180, 300)
# Y shape (131, 180, 300)
# Z shape (131, 180, 300)
# normal zsky_w True
# tdiskZ min -3558352940166464.0
# tdiskZ max 3558352940166464.0
# zf first 10 [1.49597871e+12 1.85410331e+12 2.21222792e+12 2.57035253e+12
#  2.92847713e+12 3.28660174e+12 3.64472635e+12 4.00285095e+12
#  4.36097556e+12 4.71910016e+12]
# zf last 10 [4.45570491e+14 4.45928615e+14 4.46286740e+14 4.46644864e+14
#  4.47002989e+14 4.47361114e+14 4.47719238e+14 4.48077363e+14
#  4.48435487e+14]
# zind max 1249.0
# zind min 0.0
# zind len 7074000
# plotting

# %%
# %run raytrace_3dwarp.py
#x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=60, w_i=5, w_r0=150,w_dr=40,w_pa=45, w_pos=0)
#y=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=60, w_i=5, w_r0=150,w_dr=40,w_pa=45)

# %%
# %run raytrace_3dwarp_original.py

# %%
total_model(x,imres=0.05,distance=50.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# Knu shape (131, 180, 300)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 total_model(x,imres=0.05,distance=50.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
#       2                 modfile='fits_images/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
#       3                 L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
#
# ...

# %%
total_model(z,imres=0.05,distance=50.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/disk_ecc_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 total_model(z,imres=0.05,distance=50.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
#       2                 modfile='fits_images/disk_ecc_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
#       3                 L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_last_ditch/raytrace_3dwarp_original.py:460, in total_model(disk, imres, distance, chanmin, nchans, chanstep, flipme, Jnum, freq0, xnpix, vsys, PA, offs, modfile, abund, obsv, wind, isgas, includeDust, extra, bin, hanning, L_cloud, tau, sigma_c, velocity_c, manual_chan_params, response_function)
# ...

# %%
# %run raytrace_3dwarp.py
x=original.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84)
# Out:
# X shape (131, 180)
# X_0 0.0
# X_-1 8975872242000000.0
# Y_0 0.0
# Y_-1 0.0
# on sky thickness 8511505407224490.0
# on sky thickness 2 8511505407224490.0
# zmax 448793612100000.0
# tdiskZmax 9372888615656384.0

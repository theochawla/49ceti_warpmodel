# %%
import disk_ecc as original
import disk_ecc_warp_clean as mine

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
#%run raytrace_3dwarp.py
x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=40, w_i=10, w_r0=150,w_dr=40,w_pa=0, rotation=90)
# Out:
# zcf max 448793612100000.0
# zcf min -448793612100000.0
# dz max 3001963960535.125
# dz min -897587224200000.0
# dz shape (180, 131, 300)
# Beware: removed NaNs from density (#8122)
# normal zsky_w True
# tdiskY_w[:,:,0]:[[-2.54523505e+15 -2.55394256e+15 -2.56265007e+15 ... -4.08646390e+15
#   -4.09517140e+15 -4.10387891e+15]
#  [-2.54523505e+15 -2.55393239e+15 -2.56262973e+15 ... -4.08466409e+15
#   -4.09336143e+15 -4.10205877e+15]
#  [-2.54523505e+15 -2.55390191e+15 -2.56256877e+15 ... -4.07926888e+15
#   -4.08793573e+15 -4.09660259e+15]
#  ...
#  [-2.54523505e+15 -2.55390191e+15 -2.56256877e+15 ... -4.07926888e+15
#   -4.08793573e+15 -4.09660259e+15]
#  [-2.54523505e+15 -2.55393239e+15 -2.56262973e+15 ... -4.08466409e+15
#   -4.09336143e+15 -4.10205877e+15]
#  [-2.54523505e+15 -2.55394256e+15 -2.56265007e+15 ... -4.08646390e+15
#   -4.09517140e+15 -4.10387891e+15]]
# X_rot[:,:,0]:[[ 0.00000000e+00  3.07046738e-03  6.14093475e-03 ...  5.43472726e-01
# ...

# %%
#%run raytrace_3dwarp.py
y=original.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=80)
# Out:
# X shape (131, 180)
# X_0 0.0
# X_-1 8975872242000000.0
# Y_0 0.0
# Y_-1 0.0
# on sky thickness 5073501872439494.0
# on sky thickness 2 5073501872439494.0
# zmax 448793612100000.0
# tdiskZmax 9285721174027056.0
# tdiskY:[[[-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]
#   [-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]
#   [-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]
#   ...
#   [-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]
#   [-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]
#   [-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
#     2.51129859e+15  2.52826682e+15]]
#
#  [[-2.54523505e+15 -2.52826682e+15 -2.51129859e+15 ...  2.49433035e+15
# ...

# %%
# %run raytrace_3dwarp.py
total_model(x,imres=0.05,distance=30.,chanmin=-10,nchans=20,chanstep=1,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=0,PA=312.46,offs=[0.0,0.0],
                modfile='fits_files/warp_negvel_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

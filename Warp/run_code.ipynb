# %%
import disk_ecc as original
import disk_ecc_warp_clean as mine

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
np.sin(np.deg2rad(30))*np.sin(np.deg2rad(60))
# Out:
# 0.43301270189221913

# %%
np.sin(np.deg2rad(30)+np.deg2rad(60))
# Out:
# 1.0

# %%
# %run raytrace_3dwarp.py
x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=0)
# Out:
# zcf max 448793612100000.0
# zcf min -448793612100000.0
# dz max 718644695116.125
# dz min -897587224200000.0
# dz shape (500, 131, 1250)
# Beware: removed NaNs from density (#74932)
# normal zsky_w True
# plotting

# %%
# %run raytrace_3dwarp_original.py

# %%
total_model(x,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_files/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)
# Knu shape (131, 180, 300)

# %%
import disk_ecc as original
import disk_ecc_warp as mine

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
np.sin(np.deg2rad(30))*np.sin(np.deg2rad(60))
# Out:
# 0.43301270189221913

# %%
np.sin(np.deg2rad(30)+np.deg2rad(60))
# Out:
# 1.0

# %%
# %run raytrace_3dwarp.py
x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20)
# Out:
# zmax = 448793612100000.0
# zcf min -448793612100000.0
# zcf max 448793612100000.0
# acf shape = (500, 131, 1250)
# a 0
# r0 2243968060500000.0
# dr 598391482800000.0
# r max8975872242000000.0
# r min149597870700000.0
# a 20
# r0 2243968060500000.0
# dr 598391482800000.0
# r max8975872242000000.0
# r min149597870700000.0
# warp.shape(500, 1, 1)
# twist.shape(500, 1, 1)
# siggas shape: (500, 131)
# siggas min 2.877761385725983e-05
# siggas max 0.08819236589962026
# siggas mean 0.0035865216871945236
# rho0 shape (500, 131, 1250)
# rho0 min nan
# rho0 max nan
# rho0 mean nan
# self.vel shape (500, 131, 1250)
# Beware: removed NaNs from density (#74932)
# tempg min 5.715476066494082
# tempg max 44.27188724235731
# tempg mean 10.154129491903134
# zpht_up min -448793612100000.0
# zpht_up max 415735956124659.75
# zpht_up mean 316161984458764.2
# sig_col min 0.0
# sig_col max 0.03178959227924927
# sig_col_up mean 0.0007783051016034178
# nr 180
# nphi 131
# a 0
# r0 2243968060500000.0
# dr 598391482800000.0
# r max8975872242000000.0
# r min0.0
# a 20
# r0 2243968060500000.0
# dr 598391482800000.0
# r max8975872242000000.0
# r min0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().run_line_magic('run', 'raytrace_3dwarp.py')
# ----> 2 x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:179, in Disk.__init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring, w_i, w_r0, w_dr, w_pa)
#     177 self.set_structure()  # use obs and params to create disk structure
#     178 if rtg:
# --> 179     self.set_rt_grid()
#     180     self.set_line(line=line,vcs=vcs)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:704, in Disk.set_rt_grid(self)
#     698 '''may actually have to also interpolate x and y warp grids onto these ones...'''
#     699 #X = (np.outer(R,np.cos(phi)))
#     700 #Y = (np.outer(R,np.sin(phi)))
#     701 #X = (np.outer(R,np.cos(phi))).transpose()
#     702 #Y = (np.outer(R,np.sin(phi))).transpose()
#     703 #Z = np.zeros(X.shape)
# --> 704 x_l, y_l = pol2cart(R,phi)
#     705 z_l = self.zf
#     707 '''need 3d inputs, so I'm using meshgrid'''
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:44, in pol2cart(rho, phi)
#      43 def pol2cart(rho, phi):
# ---> 44     x = rho * np.cos(phi)
#      45     y = rho * np.sin(phi)
#      46     return(x, y)
#
# ValueError: operands could not be broadcast together with shapes (180,) (131,)

# %%
# %run raytrace_3dwarp.py

# %%
total_model(x,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

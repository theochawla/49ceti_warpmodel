# %%
import numpy as np
import matplotlib.pyplot as plt
import disk_ecc_warp as warp
import disk_ecc_warp_faceontest_ as faceon
import disk_ecc as disk

# %%
inc = 60
warp_inc = 0
pa = 0

# %%
warp_model=faceon.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Ain=30, Aout=300.,incl=inc, w_i=warp_inc, w_r0=100,w_dr=40,w_pa=pa)
# Out:
# self.nr 180
# self.nphi 131
# self.nz 300
# self.zmax from obs 448793612100000.0
# zmax = 448793612100000.0
# zcf min -448793612100000.0
# zcf max 448793612100000.0
# zcf shape (500, 131, 1250)
# acf shape = (500, 131, 1250)
# a 0
# r0 1495978707000000.0
# dr 598391482800000.0
# r max4487936121000000.0
# r min448793612100000.0
# a 0
# r0 1495978707000000.0
# dr 598391482800000.0
# r max4487936121000000.0
# r min448793612100000.0
# warp.shape(500, 1, 1)
# twist.shape(500, 1, 1)
# siggas shape: (500, 131)
# siggas min 0.0004252788063693146
# siggas max 0.025727868526206902
# siggas mean 0.0041162742492905835
# ...

# %%
# %run raytrace_3dwarp.py
total_model(warp_model,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/warp_inc{}_wi{}_wpa{}_nohanning'.format(inc, warp_inc, pa),abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace_3dwarp.py:359: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace_3dwarp.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace_3dwarp.py:92: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace_3dwarp.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

# %%
nowarp_model=disk.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300., Ain=30, incl=inc)
# Out:
# self.nr 180
# self.nphi 131
# self.nz 300
# self.zmax from obs 448793612100000.0
# zmax = 448793612100000.0
# zcf shape (500, 131, 1250)
# (500, 131, 1250)
# plotting
# siggas shape: (500, 131)
# siggas min 0.00042527880636931503
# siggas max 0.025727868526206902
# siggas mean 0.004116274249290583
# rho0 shape (500, 131, 1250)
# rho0 min 4.488869993922762e-113
# rho0 max 6.782450184856551e-16
# rho0 mean 4.615617150521689e-18
# vel min -824700.7730068513
# vel max 824700.7730068513
# vel mean 3027.236163388428
# tempg min 8.08290376865476
# tempg max 25.560386016907753
# tempg mean 12.291039239619959
# zpht_up min 59512164943722.19
# zpht_up max 431603630992823.0
# zpht_up mean 325282881595720.8
# sig_col min 0.0
# sig_col max 0.012863934263103451
# sig_col_up mean 0.00023294215189570663
# rt phi(0) 0.0
# rt phi(-1) 6.283185307179586
# zsky max 897587224199999.8
# zsky min -891603309371999.8
# tdiskZ shape(131, 180, 300)
# tdiskZ min -4331333494084935.5
# ...

# %%
4.6156/2
# Out:
# 2.3078

# %%
# %run raytrace.py
total_model(nowarp_model,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/nowarp_inc{}_nohanning'.format(inc),abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace.py:356: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace.py:92: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_edgeon_troubleshoot/raytrace.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

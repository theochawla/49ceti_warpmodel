# %%
import disk_ecc as original
import disk_ecc_warp_setstructure as mine

import numpy as np
import bettermoments as bm

import matplotlib.pyplot as plt

# %%
# %run raytrace_3dwarp.py
x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20)
# Out:
# zcf max 448793612100000.0
# zcf min -448793612100000.0
# dz max 718644695116.125
# dz min -897587224200000.0
# dz shape (500, 131, 1250)
# Beware: removed NaNs from density (#74932)
# tdiskZ min -448793612100000.0
# tdiskZ max 448793612100000.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().run_line_magic('run', 'raytrace_3dwarp.py')
# ----> 2 x=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=600.,incl=84, w_i=0, w_r0=150,w_dr=40,w_pa=20)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_last_ditch/disk_ecc_warp_setstructure.py:287, in Disk.__init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring, w_i, w_r0, w_dr, w_pa, w_pos)
#     285 self.set_structure()  # use obs and params to create disk structure
#     286 if rtg:
# --> 287     self.set_rt_grid()
#     288     self.set_line(line=line,vcs=vcs)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Warp/warp_last_ditch/disk_ecc_warp_setstructure.py:1059, in Disk.set_rt_grid(self)
#    1044 #x_center = np.mean(X_w[:,:,-1].ravel())
#    1045 #y_center = np.mean(tdiskY[:,:,-1].ravel())
#    1046
#    (...)
#    1056 #tr = np.sqrt(X_w.repeat(self.nz).reshape(self.nphi,self.nr,self.nz)**2+tdiskY**2)
#    1057 #tr = np.sqrt(X_w**2+tdiskY**2)
#    1058 tr = np.sqrt(X_w**2+tdiskY**2)
# -> 1059 self.tr = np.sqrt(X_w**2, tdiskY_nosky**2)
#    1060 #tphi = np.arctan2(tdiskY,X_w.repeat(self.nz).reshape(self.nphi,self.nr,self.nz))%(2*np.pi)
#    1061 #tphi = np.arctan2(tdiskY,X)%(2*np.pi)
#    1062 tphi = np.arctan2(tdiskY,X)%(2*np.pi)
#
# NameError: name 'tdiskY_nosky' is not defined

# %%
# %run raytrace_3dwarp.py

# %%
total_model(x,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='fits_images/warp_init_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=True,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

# %%
import disk_ecc as original
import disk_ecc_warp as mine

# %%
x=original.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=800.,incl=80,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0,sigbound=[.79,1000],Rabund=[10,1000],
                 nr=150,nphi=150,nz=120,zmax=120,rtg=True,vcs=True,line='co',ring=None)
#x.plot_structure()
# Out:
# (500, 150, 1250)
# plotting
# siggas shape: (500, 150)
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:450: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
x.plot_structure()
# Out:
# self.Z shape (150, 150, 120)
# self.Z[0,:,:] shape (150, 120)
# z[0,:,:,] contents [[ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]
#  [ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]
#  [ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]
#  ...
#  [ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]
#  [ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]
#  [ 1.79517445e+15  1.76525487e+15  1.73533530e+15 ... -1.70541573e+15
#   -1.73533530e+15 -1.76525487e+15]]
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:798: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:799: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:822: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:823: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
y=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=800.,incl=80,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,1000],
                 nr=150,nphi=150,nz=120,zmax=120,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=0,w_dr=0,w_pa=0)
# Out:
# acf shape = (500, 150, 1250)
# (500, 150, 3)
# (500, 1)
# (500, 1)
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:59: RuntimeWarning: divide by zero encountered in true_divide
#   return np.radians(a / (1.0 + np.exp(-(r0 - r) / (0.1*dr))))
# siggas shape: (500, 150)
# zsky shape(120,)
# zsky min-1.016569766511391e+16
# zsky max1.033799762553957e+16
# tdiskZ shape(150, 150, 120)
# tdisk min -1.64969504919565e+16
# tdisk max 1.65268700660965e+16
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:558: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
y.plot_structure()
# Out:
# (500, 150, 1250)
# [1.49597871e+14 1.79277609e+14 2.08957346e+14 2.38637084e+14
#  2.68316822e+14 2.97996560e+14 3.27676298e+14 3.57356036e+14
#  3.87035774e+14 4.16715512e+14 4.46395249e+14 4.76074987e+14
#  5.05754725e+14 5.35434463e+14 5.65114201e+14 5.94793939e+14
#  6.24473677e+14 6.54153415e+14 6.83833152e+14 7.13512890e+14
#  7.43192628e+14 7.72872366e+14 8.02552104e+14 8.32231842e+14
UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
#For some reason my r_grid is like 10^15...

# %run raytrace.py

# %%
total_model(y,imres=0.05,distance=100.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='warp_unwarped',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:356: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:92: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

# %%
total_model(x,imres=0.05,distance=100.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='unedited_disk',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240

# %%
y.plot_structure(rmax=1000,zmax=200)
# Out:
# (500, 150, 1250)
# [1.49597871e+14 1.50984870e+14 1.52384728e+14 1.53797565e+14
#  1.55223502e+14 1.56662659e+14 1.58115159e+14 1.59581126e+14
#  1.61060684e+14 1.62553961e+14 1.64061082e+14 1.65582177e+14
#  1.67117375e+14 1.68666806e+14 1.70230603e+14 1.71808898e+14
#  1.73401827e+14 1.75009524e+14 1.76632128e+14 1.78269775e+14
#  1.79922606e+14 1.81590761e+14 1.83274382e+14 1.84973614e+14
#  1.86688599e+14 1.88419485e+14 1.90166419e+14 1.91929550e+14
#  1.93709028e+14 1.95505004e+14 1.97317631e+14 1.99147064e+14
#  2.00993459e+14 2.02856973e+14 2.04737765e+14 2.06635994e+14
#  2.08551822e+14 2.10485414e+14 2.12436932e+14 2.14406544e+14
#  2.16394418e+14 2.18400722e+14 2.20425627e+14 2.22469307e+14
#  2.24531934e+14 2.26613685e+14 2.28714737e+14 2.30835269e+14
#  2.32975462e+14 2.35135497e+14 2.37315560e+14 2.39515834e+14
#  4.80772303e+15 4.85229790e+15 4.89728605e+15 4.94269131e+15
#  4.98851755e+15 5.03476866e+15 5.08144859e+15 5.12856132e+15
#  5.17611085e+15 5.22410124e+15 5.27253657e+15 5.32142097e+15
#  5.37075860e+15 5.42055367e+15 5.47081041e+15 5.52153311e+15
#  5.57272608e+15 5.62439369e+15 5.67654034e+15 5.72917047e+15
#  5.78228856e+15 5.83589913e+15 5.89000675e+15 5.94461604e+15
#  5.99973163e+15 6.05535823e+15 6.11150057e+15 6.16816344e+15
#  6.22535166e+15 6.28307010e+15 6.34132367e+15 6.40011735e+15
#  6.45945613e+15 6.51934507e+15 6.57978928e+15 6.64079389e+15
#  6.70236411e+15 6.76450517e+15 6.82722238e+15 6.89052107e+15
#  6.95440664e+15 7.01888452e+15 7.08396022e+15 7.14963926e+15
#  7.21592724e+15 7.28282982e+15 7.35035268e+15 7.41850158e+15
#  7.48728233e+15 7.55670078e+15 7.62676284e+15 7.69747448e+15
#  7.76884173e+15 7.84087066e+15 7.91356740e+15 7.98693816e+15
#  8.06098917e+15 8.13572675e+15 8.21115726e+15 8.28728713e+15
#  8.36412283e+15 8.44167092e+15 8.51993799e+15 8.59893072e+15
#  8.67865584e+15 8.75912012e+15 8.84033043e+15 8.92229368e+15
#  9.00501686e+15 9.08850701e+15 9.17277123e+15 9.25781671e+15
#  9.34365070e+15 9.43028049e+15 9.51771347e+15 9.60595709e+15
#  9.69501887e+15 9.78490638e+15 9.87562728e+15 9.96718930e+15
#  1.00596002e+16 1.01528680e+16 1.02470004e+16 1.03420057e+16
#  1.04378917e+16 1.05346668e+16 1.06323391e+16 1.07309170e+16
#  1.08304088e+16 1.09308231e+16 1.10321684e+16 1.11344533e+16
#  1.12376866e+16 1.13418769e+16 1.14470333e+16 1.15531647e+16
#  1.16602800e+16 1.17683885e+16 1.18774992e+16 1.19876216e+16
#  1.20987651e+16 1.22109389e+16 1.23241528e+16 1.24384164e+16
#  1.25537394e+16 1.26701315e+16 1.27876028e+16 1.29061633e+16
#  1.30258230e+16 1.31465921e+16 1.32684809e+16 1.33914998e+16
#  1.35156593e+16 1.36409699e+16 1.37674424e+16 1.38950874e+16
#  1.40239159e+16 1.41539389e+16 1.42851673e+16 1.44176125e+16
#  1.45512856e+16 1.46861980e+16 1.48223613e+16 1.49597871e+16]
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:1289: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:1290: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:1313: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:1314: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
from astropy.io import fits

# %%
unwarped = fits.open('testpy_alma.fits')
unwarped.info()
# Out:
# Filename: testpy_alma.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (512, 512, 15)   float64

# %%
og_with_params = original.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=5,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
# Out:
# (500, 131, 1250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-baa3cc237e04> in <module>
#       2                  Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
# ----> 4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in __init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring)
#      65         self.set_params(params) # set the structure parameters
#      66
# ---> 67         self.set_structure()  # use obs and params to create disk structure
#      68         if rtg:
#      69             self.set_rt_grid()
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in set_structure(self)
#     372                 foo[0] = 0
#     373                 nsl = foo.cumsum()
# --> 374                 sig_col[ia,jf,:] = nsl[::-1]*Disk.m0/Disk.Hnuctog
#     375                 pht = (np.abs(nsl) >= self.sigbound[0])
#     376                 if pht.sum() == 0:
#
# KeyboardInterrupt:

# %%
'''
z=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],
                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)

'''
# Out:
# "\nz=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,\n                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,\n                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],\n                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)\n\n"

# %%
z.plot_structure(rmax=110,zmax=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6a06a639ff84> in <module>
# ----> 1 z.plot_structure(rmax=110,zmax=100)
#
# NameError: name 'z' is not defined

# %%
og_with_params.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:809: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:810: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:833: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:834: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
                 Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb8be7cb260d> in <module>
# ----> 1 mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
#       2                  Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
#       4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
#
# NameError: name 'mine' is not defined

# %%
mine_with_params.plot_structure(rmax=200, zmax=10)

# %%
run raytrace.py

# %%
hdul = fits.open('warp_unwarped.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(2-1) in Hz
hdul.flush()
hdul.close()

# %%
import disk_ecc as original
import disk_ecc_warp_faceontest_ as mine

import numpy as np

# %%
#x = original.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=15)

# %%
y=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=100.,incl=25, w_i=40, w_r0=20,w_dr=40,w_pa=-45)
# Out:
# zmax = 448793612100000.0
# acf shape = (500, 131, 1250)
# a 40
# r0 299195741400000.0
# dr 598391482800000.0
# r max1495978707000000.0
# r min149597870700000.0
# a -45
# r0 299195741400000.0
# dr 598391482800000.0
# r max1495978707000000.0
# r min149597870700000.0
# warp.shape(500, 1, 1)
# twist.shape(500, 1, 1)
# siggas shape: (500, 131)
# siggas min 0.004840099658556031
# siggas max 2.3642821174247914
# siggas mean 0.01931420855517347
# rho0 shape (500, 131, 1250)
# rho0 min nan
# rho0 max nan
# rho0 mean nan
# Beware: removed NaNs from density (#1172776)
# tempg min 14.0
# tempg max 44.27188724235731
# tempg mean 21.2887044408446
# zpht_up min -524070839881304.5
# zpht_up max 218108667119754.25
# zpht_up mean 96445590725543.4
# sig_col min 0.0
# sig_col max 0.05343525594760273
# sig_col_up mean 0.0037504394349948075
# nr 180
# nphi 131
# nz 300
# grid shape (131, 180, 300)
# a 40
# r0 299195741400000.0
# dr 598391482800000.0
# r max1495978707000000.0
# r min0.0
# a -45
# r0 299195741400000.0
# dr 598391482800000.0
# r max1495978707000000.0
# r min0.0
# X shape (131, 180, 300)
# Y shape (131, 180, 300)
# Z shape (131, 180, 300)
# warp.shape(1, 180, 1)
# twist.shape(1, 180, 1)
# tdiskZ shape(131, 180, 300)
# tdiskZ min -1038788462868268.8
# tdiskZ max 1038788462868268.8
# zind max 1249.0
# zind min 0.0
# zind len 7074000
# phiind max 129.99999102923397
# phiind min 1.271432930908282e-05
# phiind len 7074000
# aind max 500.0
# aind min 0.0
# aind len 7074000
# tempg shape (500, 131, 1250)
# tT shape (131, 180, 300)

# %%
y.plot_structure()

# %%
# %run raytrace_3dwarp.py

# %%
total_model(y,imres=0.05,distance=20.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='zuleta_replica',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace_3dwarp.py:359: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace_3dwarp.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace_3dwarp.py:92: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace_3dwarp.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

# %%
# %run raytrace.py

# %%
x.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  ...
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]]
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:879: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:880: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:903: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:904: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
total_model(x,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='no-warp',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:356: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:92: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py:102: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

# %%
y=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=85, w_i=20, w_r0=150,w_dr=10,w_pa=0)
# Out:
# zmax = 448793612100000.0
# acf shape = (500, 131, 1250)
# a 20
# r0 747989353500000.0
# dr 149597870700000.0
# r max4487936121000000.0
# r min149597870700000.0
# a 0
# r0 747989353500000.0
# dr 149597870700000.0
# r max4487936121000000.0
# r min149597870700000.0
# (500, 131, 3)
# (500, 1)
# (500, 1)
# siggas shape: (500, 131)
# siggas min 0.0004252788063693142
# siggas max 0.09459221542575506
# siggas mean 0.007217691859206746
# rho0 shape (500, 131, 1250)
# rho0 min 0.0
# rho0 max 1.3580135785870548e-13
# rho0 mean 8.457103329650703e-18
# tempg min 8.08290376865476
# tempg max 44.27188724235731
# tempg mean 13.695243393019407
# zpht_up min 14056471517097.688
# zpht_up max 433099609699823.0
# zpht_up mean 310038866274284.4
# sig_col min 0.0
# sig_col max 0.04729610771287714
# sig_col_up mean 0.0003933086850416065
# zsky shape(300,)
# zsky min-4475045445834560.0
# zsky max4505079307887141.0
# tdiskZ shape(131, 180, 300)
# tdisk min -4859578651141035.0
# tdisk max 4862196274695808.0

# %%
#x=original.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=70 )

# %%
y.plot_structure()
# Out:
# (500, 131, 1250)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-87a5e749bbdb> in <module>
# ----> 1 y.plot_structure()
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp_faceontest_.py in plot_structure(self, sound_speed, beta, dust, rmax, zmax)
#    1384         '''theo: adding some extra plots and print statements to make sure warp structure is correct'''
#    1385         print(self.rcf.shape)
# -> 1386         print(self.rotation[:,-1,0])
#    1387
#    1388         plt.scatter(self.rotation[:,:,0], self.rotation[:,:,1], c=self.rotation[:,:,2])
#
# AttributeError: 'Disk' object has no attribute 'rotation'

# %%
#x=original.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=800.,incl=80,
                 #Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 #handed=-1,ecc=0.,aop=0,sigbound=[.79,1000],Rabund=[10,1000],
                 #nr=150,nphi=150,nz=120,zmax=120,rtg=True,vcs=True,line='co',ring=None)
#x.plot_structure()

# %%
x.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  ...
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]]
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:811: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:812: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:835: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc.py:836: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
#y=mine.Disk(Tmid0=14, Rc=100., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=70, w_i=0, w_r0=0,w_dr=0,w_pa=0)
y=mine.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=70)
# Out:
# acf shape = (500, 131, 1250)
# (500, 131, 3)
# (500, 1)
# (500, 1)
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:59: RuntimeWarning: overflow encountered in exp
#   return np.radians(a / (1.0 + np.exp(-(r0 - r) / (0.1*dr))))
# siggas shape: (500, 131)
# zsky shape(300,)
# zsky min-1303436839570912.0
# zsky max1312184737823065.5
# tdiskZ shape(131, 180, 300)
# tdisk min -4661850723635361.0
# tdisk max 4664842681049361.0
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py:565: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))

# %%
y.plot_structure()
# Out:
# (500, 131, 1250)
# [1.49597871e+14 1.58291935e+14 1.66986000e+14 1.75680065e+14
#  1.84374129e+14 1.93068194e+14 2.01762258e+14 2.10456323e+14
#  2.19150388e+14 2.27844452e+14 2.36538517e+14 2.45232582e+14
#  2.53926646e+14 2.62620711e+14 2.71314776e+14 2.80008840e+14
#  2.88702905e+14 2.97396969e+14 3.06091034e+14 3.14785099e+14
#  3.23479163e+14 3.32173228e+14 3.40867293e+14 3.49561357e+14
#  3.58255422e+14 3.66949486e+14 3.75643551e+14 3.84337616e+14
#  3.93031680e+14 4.01725745e+14 4.10419810e+14 4.19113874e+14
#  4.27807939e+14 4.36502003e+14 4.45196068e+14 4.53890133e+14
UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
#For some reason my r_grid is like 10^15...

# %run raytrace.py

# %%
total_model(y,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='3d_grid_warp',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d160a2fafcd5> in <module>
#       1 total_model(y,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
#       2                 modfile='3d_grid_warp',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
# ----> 3                 L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
#       4
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py in total_model(disk, imres, distance, chanmin, nchans, chanstep, flipme, Jnum, freq0, xnpix, vsys, PA, offs, modfile, abund, obsv, wind, isgas, includeDust, extra, bin, hanning, L_cloud, tau, sigma_c, velocity_c, manual_chan_params, response_function)
#     432
#     433     # - interpolate onto a square grid
# --> 434     im = xy_interpol(cube,X*arcsec,Y*arcsec,xnpix=xnpix,imres=imres,flipme=flipme)
#     435
#     436     if isgas:
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/raytrace.py in xy_interpol(cube, dec, ra, xnpix, imres, flipme)
#     616
#     617     # - do interpolation
# --> 618     iR = np.interp(pR,r,range(nr))
#     619     iPhi = np.interp(pPhi,phi,range(nphi))
#     620
#
# <__array_function__ internals> in interp(*args, **kwargs)
#
# /soft/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in interp(x, xp, fp, left, right, period)
#    1426         fp = np.concatenate((fp[-1:], fp, fp[0:1]))
#    1427
# -> 1428     return interp_func(x, xp, fp, left, right)
#    1429
#    1430
#
# ValueError: object too deep for desired array

# %%
#debris disk parameters for unedited disk

# %%
x.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  ...
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]
#  [ 4.48793612e+14  4.45801655e+14  4.42809697e+14 ... -4.39817740e+14
#   -4.42809697e+14 -4.45801655e+14]]

# %%
total_model(x,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=True,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='dd_unedited_disk',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240

# %%
#y=mine.Disk(Tmid0=14, Rc=100., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=70, w_i=0, w_r0=0,w_dr=0,w_pa=0)
y=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=85, w_i=60, w_r0=100,w_dr=10,w_pa=0)
# Out:
# acf shape = (500, 131, 1250)
# (500, 131, 3)
# (500, 1)
# (500, 1)
# siggas shape: (500, 131)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-652d9038463f> in <module>
#       1 #y=mine.Disk(Tmid0=14, Rc=100., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=70, w_i=0, w_r0=0,w_dr=0,w_pa=0)
# ----> 2 y=mine.Disk(Tmid0=14, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=85, w_i=60, w_r0=100,w_dr=10,w_pa=0)
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py in __init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring, w_i, w_r0, w_dr, w_pa)
#     133         self.set_params(params) # set the structure parameters
#     134
# --> 135         self.set_structure()  # use obs and params to create disk structure
#     136         if rtg:
#     137             self.set_rt_grid()
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py in set_structure(self)
#     348
#     349         ## Add an extra ring
# --> 350         if self.ring is not None:
#     351             w = np.abs(rcf-self.Rring)<self.Wring/2.
#     352             if w.sum()>0:
#
# /Volumes/disks/theo/49ceti_warpmodel/Warp/disk_ecc_warp.py in calc_hydrostatic(self, tempg, siggas, grid)
#     834         dlnp[:,:,0] = -1.*grvc*zcf[:,:,0]/(tempg[:,:,0]*(rcf[:,:,0]**2.+zcf[:,:,0]**2.)**1.5)
#     835
# --> 836         #numerical integration to get vertical density profile
#     837         foo = dz*(dlnp+np.roll(dlnp,1,axis=2))/2.
#     838         foo[:,:,0] = np.zeros((nac,nfc))
#
# KeyboardInterrupt:

# %%
y.plot_structure(rmax=300,zmax=50)
# Out:
# (500, 131, 1250)
# [1.49597871e+14 1.58291935e+14 1.66986000e+14 1.75680065e+14
#  1.84374129e+14 1.93068194e+14 2.01762258e+14 2.10456323e+14
#  2.19150388e+14 2.27844452e+14 2.36538517e+14 2.45232582e+14
#  2.53926646e+14 2.62620711e+14 2.71314776e+14 2.80008840e+14
#  2.88702905e+14 2.97396969e+14 3.06091034e+14 3.14785099e+14
#  3.23479163e+14 3.32173228e+14 3.40867293e+14 3.49561357e+14
#  3.58255422e+14 3.66949486e+14 3.75643551e+14 3.84337616e+14
#  3.93031680e+14 4.01725745e+14 4.10419810e+14 4.19113874e+14
#  4.27807939e+14 4.36502003e+14 4.45196068e+14 4.53890133e+14
#  4.62584197e+14 4.71278262e+14 4.79972327e+14 4.88666391e+14
#  4.97360456e+14 5.06054521e+14 5.14748585e+14 5.23442650e+14
#  5.32136714e+14 5.40830779e+14 5.49524844e+14 5.58218908e+14
#  5.66912973e+14 5.75607038e+14 5.84301102e+14 5.92995167e+14
#  6.01689231e+14 6.10383296e+14 6.19077361e+14 6.27771425e+14
#  6.36465490e+14 6.45159555e+14 6.53853619e+14 6.62547684e+14
#  6.71241748e+14 6.79935813e+14 6.88629878e+14 6.97323942e+14
#  3.48811869e+15 3.49681275e+15 3.50550682e+15 3.51420088e+15
#  3.52289495e+15 3.53158901e+15 3.54028308e+15 3.54897714e+15
#  3.55767121e+15 3.56636527e+15 3.57505933e+15 3.58375340e+15
#  3.59244746e+15 3.60114153e+15 3.60983559e+15 3.61852966e+15
#  3.62722372e+15 3.63591779e+15 3.64461185e+15 3.65330592e+15
#  3.66199998e+15 3.67069405e+15 3.67938811e+15 3.68808218e+15
#  3.69677624e+15 3.70547030e+15 3.71416437e+15 3.72285843e+15
#  3.73155250e+15 3.74024656e+15 3.74894063e+15 3.75763469e+15
#  3.76632876e+15 3.77502282e+15 3.78371689e+15 3.79241095e+15
#  3.80110502e+15 3.80979908e+15 3.81849314e+15 3.82718721e+15
#  3.83588127e+15 3.84457534e+15 3.85326940e+15 3.86196347e+15
#  3.87065753e+15 3.87935160e+15 3.88804566e+15 3.89673973e+15
#  3.90543379e+15 3.91412786e+15 3.92282192e+15 3.93151598e+15
#  3.94021005e+15 3.94890411e+15 3.95759818e+15 3.96629224e+15
#  3.97498631e+15 3.98368037e+15 3.99237444e+15 4.00106850e+15
#  4.00976257e+15 4.01845663e+15 4.02715070e+15 4.03584476e+15
#  4.04453882e+15 4.05323289e+15 4.06192695e+15 4.07062102e+15
#  4.07931508e+15 4.08800915e+15 4.09670321e+15 4.10539728e+15
#  4.11409134e+15 4.12278541e+15 4.13147947e+15 4.14017354e+15
#  4.14886760e+15 4.15756167e+15 4.16625573e+15 4.17494979e+15
#  4.18364386e+15 4.19233792e+15 4.20103199e+15 4.20972605e+15
#  4.21842012e+15 4.22711418e+15 4.23580825e+15 4.24450231e+15
#  4.25319638e+15 4.26189044e+15 4.27058451e+15 4.27927857e+15
#  4.28797263e+15 4.29666670e+15 4.30536076e+15 4.31405483e+15
#  4.32274889e+15 4.33144296e+15 4.34013702e+15 4.34883109e+15
#  4.35752515e+15 4.36621922e+15 4.37491328e+15 4.38360735e+15
#  4.39230141e+15 4.40099547e+15 4.40968954e+15 4.41838360e+15
#  4.42707767e+15 4.43577173e+15 4.44446580e+15 4.45315986e+15
#  4.46185393e+15 4.47054799e+15 4.47924206e+15 4.48793612e+15]

# %%
total_model(y,imres=0.05,distance=40.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=312.46,offs=[0.0,0.0],
                modfile='dd_warped',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

# %%
from astropy.io import fits

# %%
unwarped = fits.open('testpy_alma.fits')
unwarped.info()
# Out:
# Filename: testpy_alma.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (512, 512, 15)   float64

# %%
og_with_params = original.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=5,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
# Out:
# (500, 131, 1250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-baa3cc237e04> in <module>
#       2                  Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=.5,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
# ----> 4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None)
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in __init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring)
#      65         self.set_params(params) # set the structure parameters
#      66
# ---> 67         self.set_structure()  # use obs and params to create disk structure
#      68         if rtg:
#      69             self.set_rt_grid()
#
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py in set_structure(self)
#     372                 foo[0] = 0
#     373                 nsl = foo.cumsum()
# --> 374                 sig_col[ia,jf,:] = nsl[::-1]*Disk.m0/Disk.Hnuctog
#     375                 pht = (np.abs(nsl) >= self.sigbound[0])
#     376                 if pht.sum() == 0:
#
# KeyboardInterrupt:

# %%
'''
z=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,
                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],
                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)

'''
# Out:
# "\nz=mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=100.,Rc=80.,incl=1,\n                 Mstar=1,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,\n                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,100],Rabund=[10,100],\n                 nr=50,nphi=50,nz=20,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e15,w_dr=1e15,w_pa=0)\n\n"

# %%
z.plot_structure(rmax=110,zmax=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6a06a639ff84> in <module>
# ----> 1 z.plot_structure(rmax=110,zmax=100)
#
# NameError: name 'z' is not defined

# %%
og_with_params.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:809: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:810: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:833: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/disk_ecc.py:834: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
                 Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
                 handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
                 nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb8be7cb260d> in <module>
# ----> 1 mine_with_params = mine.Disk(q=-0.5,McoG=0.09,pp=1.,Ain=10.,Aout=1000.,Rc=150.,incl=1,
#       2                  Mstar=2.3,Xco=1e-4,vturb=0.01,Zq0=33.9,Tmid0=19.,Tatm0=69.3,
#       3                  handed=-1,ecc=0.,aop=0.,sigbound=[.79,1000],Rabund=[10,800],
#       4                  nr=180,nphi=131,nz=300,zmax=170,rtg=True,vcs=True,line='co',ring=None,w_i=0, w_r0=1e14,w_dr=1e14,w_pa=60)
#
# NameError: name 'mine' is not defined

# %%
mine_with_params.plot_structure(rmax=200, zmax=10)

# %%
run raytrace.py

# %%
hdul = fits.open('warp_unwarped.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(2-1) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('zuleta_replica.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(2-1) in Hz
hdul.flush()
hdul.close()

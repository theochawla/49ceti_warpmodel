# %%
import giggle_my_version as giggle
import numpy as np 
import matplotlib.pyplot as plt

import math
#from scipy import ndimage as ndimage
import disk_ecc_spiral as disk
import disk_ecc as kevindisk
#import disk_ecc_spiral_pp as proto
#from astropy import units as u
#from astropy.constants import G, sigma_sb, k_B, m_p

#from scipy.interpolate import LinearNDInterpolator as interpnd

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
x = disk.Disk(Aout=100.,incl=30, Mstar=1, Ain=1, proto=True, md=.3, beta=5, ap=15, m=2, p=-1, Rc=50, surf_amp=0.5)
# Out:
# g_phi max3.139086393173205
# g_phi min-3.139086393173205
# g_r_tiled.shape (480000,)
# g_phi_tiled.shape (480000,)
# tile max 9.422271700352791
# tile min 3.1440989140063813
# spir_tiled.shape (480000,)
# spir_tiled_masked.shape (183092,)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/disk_ecc_spiral.py:497: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas))
# 3.400192105385863e-12
# rho0 max 3.400192105385863e-12
# phi_vel shape (400, 400)
# phi_flat-vel length160000
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/disk_ecc_spiral.py:644: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   plt.pcolor(x_pol_grid, y_pol_grid, self.vel_phi[:,:,0])
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/disk_ecc_spiral.py:657: UserWarning: The input coordinates to pcolor are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolor.
#   plt.pcolor(x_pol_grid, y_pol_grid, self.vel_rad[:,:,0])
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/disk_ecc_spiral.py:810: RuntimeWarning: divide by zero encountered in divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))
# tempg max 49.05778905196061

# %%
#y = kevindisk.Disk(zmax=10)
y = kevindisk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=85)
# Out:
# 1d z-array [1.49597871e+12 1.85410331e+12 2.21222792e+12 ... 4.48077363e+14
#  4.48435487e+14 4.48793612e+14]
# (500, 131, 1250)
# siggas[[2.31550817e-01 2.31550817e-01 2.31550817e-01 ... 2.31550817e-01
#   2.31550817e-01 2.31550817e-01]
#  [2.16304238e-01 2.16304238e-01 2.16304238e-01 ... 2.16304238e-01
#   2.16304238e-01 2.16304238e-01]
#  [2.02672976e-01 2.02672976e-01 2.02672976e-01 ... 2.02672976e-01
#   2.02672976e-01 2.02672976e-01]
#  ...
#  [2.40103669e-05 2.40103669e-05 2.40103669e-05 ... 2.40103669e-05
#   2.40103669e-05 2.40103669e-05]
#  [2.36868393e-05 2.36868393e-05 2.36868393e-05 ... 2.36868393e-05
#   2.36868393e-05 2.36868393e-05]
#  [2.33677591e-05 2.33677591e-05 2.33677591e-05 ... 2.33677591e-05
#   2.33677591e-05 2.33677591e-05]]
# self.vel min -1428423.6398891942
# self.vel max1428423.6398891942
# self.vel mean 3373.0862994978584
# R min0.0
# R max4487936121000000.0
# phi min0.0
# phi max6.283185307179586
# zind min 0.0
# zind max 1249.0
# zind mean 1083.4904044712005
# phiind min 0.0
# phiind max 130.0
# phiind mean 65.10795777814252
# aind min 0.0
# aind max 500.0
# aind mean 312.5315034610393
# self.vel min -1428423.6398891942
# self.vel max 1428423.6398891942
# tvel.shape (131, 180, 300)
# tvel min -1428423.6398891942
# zpht_up shape (131, 180, 300)

# %%
#%run raytrace_spiral.py

# %%
#otal_model(x, modfile="whynans")

# %run raytrace.py
total_model(x,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=-71.4,offs=[0.0,0.0],
                modfile='spiral_test',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/raytrace.py:400: RuntimeWarning: divide by zero encountered in divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/raytrace.py:113: RuntimeWarning: divide by zero encountered in divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# rhoG max 583519.2847289308
# rhoG shape (131, 180, 300)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/raytrace.py:113: RuntimeWarning: invalid value encountered in divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/spiral_model_for_fits/raytrace.py:128: RuntimeWarning: divide by zero encountered in divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function
# Inu shape (131, 180)
# Inu max 9.289266148865496e-13
# Inu shape (131, 180)
# Inu max 1.0294296530686735e-12
# Inu shape (131, 180)
# Inu max 9.171722639403895e-13
# Inu shape (131, 180)
# Inu max 9.680627671082791e-13
# Inu shape (131, 180)
# Inu max 8.842982629275091e-13
# Inu shape (131, 180)
# Inu max 8.844442772397346e-13
# Inu shape (131, 180)
# Inu max 1.0357670917297782e-12
# Inu shape (131, 180)
# Inu max 4.609850025286493e-13
# Inu shape (131, 180)
# Inu max 1.0357714253077501e-12
# Inu shape (131, 180)
# Inu max 8.844505905330953e-13
# Inu shape (131, 180)
# Inu max 8.843058207325834e-13
# Inu shape (131, 180)
# Inu max 9.68079077660465e-13
# Inu shape (131, 180)
# Inu max 9.171870300483753e-13
# Inu shape (131, 180)
# Inu max 1.0294516747818531e-12
# Inu shape (131, 180)
# Inu max 9.289573047975167e-13
# cube max1.0357714253077501e-12
# cube shape (131, 180, 15)
# X max4487936121000000.0
# Y max 4486625706843676.0
# X shape (131, 180)
# im max7.943545244183368e-13
# im shape (512, 512, 15)
# im_s max7.495650233552104e-13
# im_s shape (512, 512, 15)

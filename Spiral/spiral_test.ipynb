# %%
import giggle_functions as giggle
import numpy as np 
import matplotlib.pyplot as plt

import math
#from scipy import ndimage as ndimage
import disk_ecc_spiral as disk
import disk_ecc as kevindisk
import disk_ecc_spiral_pp as proto
#from astropy import units as u
#from astropy.constants import G, sigma_sb, k_B, m_p

#from scipy.interpolate import LinearNDInterpolator as interpnd

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
x = disk.Disk(Aout=100.,incl=30, Mstar=1, Ain=1, proto=True, md=.3, beta=5, ap=15, m=2, p=-1, Rc=50)
# Out:
# g_phi max6.281933743377506
# g_phi min0.0012515638020809128
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:346: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(gx, gy, g_phi)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:353: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(g_r, g_phi, g_phi)
# g_r_tiled.shape (1920000,)
# g_phi_tiled.shape (1920000,)
# tile max 12.565119050557092
# tile min 6.284436870981667
# spir_tiled.shape (1920000,)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:437: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(acf[:,:,0]/Disk.AU, fcf[:,:,0], interp_test(acf[:,:,0]/Disk.AU, fcf[:,:,0]))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:457: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:463: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas_unscale))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/giggle_my_version.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   return ((2+p)*md)/(2*np.pi*rin**2) * (x**(2+p) -1)**(-1)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/giggle_my_version.py:45: RuntimeWarning: invalid value encountered in double_scalars
#   return ((2+p)*md)/(2*np.pi*rin**2) * (x**(2+p) -1)**(-1)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/giggle_my_version.py:76: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return quad(integrand, 1/2 * rin, 2*rout, args=(r,z,md,p,rin,rout))[0]
# phi_vel shape (800, 800)
# phi_flat-vel length640000
# phi_vel min nan
# phi_vel max nan
# phi_vel mean nan
# self.vel_phi min 0.0
# self.vel_phi max 0.0
# self.vel_phi mean 0.0
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:717: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))
# vel_rad shape (131, 180, 300)
# vel_phi shape (131, 180, 300)

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
x = disk.Disk(Aout=400.,incl=30, Mstar=1, Ain=1, proto=True, md=.3, beta=5, ap=15, m=2, p=-1)
# Out:
# g_phi max6.281933743377506
# g_phi min0.0012515638020809128
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:346: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(gx, gy, g_phi)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:353: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(g_r, g_phi, g_phi)
# g_r_tiled.shape (1920000,)
# g_phi_tiled.shape (1920000,)
# tile max 12.565119050557092
# tile min 6.284436870981667
# spir_tiled.shape (1920000,)
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:437: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(acf[:,:,0]/Disk.AU, fcf[:,:,0], interp_test(acf[:,:,0]/Disk.AU, fcf[:,:,0]))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:457: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:463: RuntimeWarning: invalid value encountered in log10
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas_unscale))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:463: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x_pol_grid, y_pol_grid, np.log10(siggas_unscale))
# phi_vel shape (800, 800)
# phi_flat-vel length640000

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
x_whyassym = disk.Disk(Aout=100.,incl=30, Mstar=1, Ain=1, proto=True, md=.3, beta=5, ap=30, m=2, p=-1)

# %%
#x = disk.Disk(zmax=500)

# %%
#y = kevindisk.Disk(zmax=10)
y = kevindisk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=300.,incl=85)
# Out:
# 1d z-array [1.49597871e+12 1.85410331e+12 2.21222792e+12 ... 4.48077363e+14
#  4.48435487e+14 4.48793612e+14]
# (500, 131, 1250)
# siggas[[2.31550817e-01 2.31550817e-01 2.31550817e-01 ... 2.31550817e-01
#   2.31550817e-01 2.31550817e-01]
#  [2.16304238e-01 2.16304238e-01 2.16304238e-01 ... 2.16304238e-01
#   2.16304238e-01 2.16304238e-01]
#  [2.02672976e-01 2.02672976e-01 2.02672976e-01 ... 2.02672976e-01
#   2.02672976e-01 2.02672976e-01]
#  ...
#  [2.40103669e-05 2.40103669e-05 2.40103669e-05 ... 2.40103669e-05
#   2.40103669e-05 2.40103669e-05]
#  [2.36868393e-05 2.36868393e-05 2.36868393e-05 ... 2.36868393e-05
#   2.36868393e-05 2.36868393e-05]
#  [2.33677591e-05 2.33677591e-05 2.33677591e-05 ... 2.33677591e-05
#   2.33677591e-05 2.33677591e-05]]
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:332: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(pcf[:,:,0], acf[:,:,0], self.vel[:,:,0], cmap='viridis')
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:339: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(pcf[:,:,0], acf[:,:,0], self.vel[:,:,60], cmap='viridis')
# self.vel min -1428423.6398891942
# self.vel max1428423.6398891942
# self.vel mean 3373.086299497867
# R min0.0
# R max4487936121000000.0
# phi min0.0
# phi max6.283185307179586
# zind min 0.0
# zind max 1249.0
# zind mean 1083.4904044712005
# phiind min 0.0
# phiind max 130.0
# phiind mean 65.10795777814252
# aind min 0.0
# aind max 500.0
# aind mean 312.5315034610393
# self.vel min -1428423.6398891942
# self.vel max 1428423.6398891942
# tvel.shape (131, 180, 300)
# tvel min -1428423.6398891942
# zpht_up shape (131, 180, 300)

# %%
#y = kevindisk.Disk(zmax=500)

# %%
x.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  ...
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]]
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:1111: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:1112: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:1135: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py:1136: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
y.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]
#  [ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]
#  [ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]
#  ...
#  [ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]
#  [ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]
#  [ 3.92643533e+14  3.90025910e+14  3.87408286e+14 ... -3.84790663e+14
#   -3.87408286e+14 -3.90025910e+14]]
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:996: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:997: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[int(self.nphi/2),:,:])+4,np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:1020: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[0,:,:],(20,40,60,80,100,120),colors='k',ls='--')
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:1021: UserWarning: The following kwargs were not used by contour: 'ls'
#   cs3 = plt.contour(-self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,self.T[int(self.nphi/2.),:,:],(20,40,60,80,100,120),colors='k',ls='--')

# %%
# %run raytrace_spiral.py

# %%
#otal_model(x, modfile="whynans")

total_model(x, modfile="longarini_copy", flipme=False, distance=30, PA=90)
# Out:
# cube.shape (131, 180, 15)
# disk.X shape (131, 180)
# disk.Y shape (131, 180)
# disk.X shape (131, 180)
# rhoG max 9138672.141206075
# rhoG shape (131, 180, 300)
# tnl [[[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.35674438e-17 3.22856002e-17 3.10015272e-17 ... 2.94293360e-17
#    3.06541383e-17 3.20695514e-17]
#   [3.36302201e-17 3.23507695e-17 3.10754979e-17 ... 2.94346897e-17
#    3.06700415e-17 3.20584774e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.34239037e-17 3.21279854e-17 3.08405745e-17 ... 2.95874044e-17
#    3.08426709e-17 3.21980645e-17]
#   [3.33447205e-17 3.20343112e-17 3.07564159e-17 ... 2.97470547e-17
#    3.10404093e-17 3.23228683e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.32805970e-17 3.19708664e-17 3.06834535e-17 ... 2.97439488e-17
#    3.10310973e-17 3.23264899e-17]
#   [3.30596402e-17 3.17163689e-17 3.04425620e-17 ... 3.00505374e-17
#    3.14113365e-17 3.25873554e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  ...
#
#  [[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.39151921e-17 3.26008261e-17 3.13260069e-17 ... 2.91149173e-17
#    3.03401744e-17 3.18135641e-17]
#   [3.43068204e-17 3.29849543e-17 3.17240115e-17 ... 2.88101805e-17
#    3.00650314e-17 3.15026396e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.37414388e-17 3.24433384e-17 3.11638971e-17 ... 2.92718100e-17
#    3.04794343e-17 3.19412766e-17]
#   [3.39769634e-17 3.26679051e-17 3.13996975e-17 ... 2.91215909e-17
#    3.03468467e-17 3.17949032e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.35239715e-17 3.22381739e-17 3.09458867e-17 ... 2.94418474e-17
#    3.06593597e-17 3.20951910e-17]
#   [3.35674438e-17 3.22856002e-17 3.10015272e-17 ... 2.94293360e-17
#    3.06541383e-17 3.20695514e-17]
#   [3.36302201e-17 3.23507695e-17 3.10754979e-17 ... 2.94346897e-17
#    3.06700415e-17 3.20584774e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]]
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace_spiral.py:435: RuntimeWarning: divide by zero encountered in true_divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1346796.501776284
# dV min-1780197.2921726347
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace_spiral.py:138: RuntimeWarning: divide by zero encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace_spiral.py:138: RuntimeWarning: invalid value encountered in true_divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace_spiral.py:151: RuntimeWarning: divide by zero encountered in true_divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086064880005796e-11
# Knu shape (131, 180, 300)
# Knu mas 4.796398616506357e-10
# tau first z slice max0.0
# arg first z slice max 3.886614562079406e-49
# gas model output 1 max 9.046512107937951e-12
# gas model output 2 =tau
# gas model output 3 max 9.046512107937951e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.046512107937951e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1378796.501776284
# dV min-1748197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086071435894982e-11
# Knu shape (131, 180, 300)
# Knu mas 4.5018955658204026e-10
# tau first z slice max0.0
# arg first z slice max 1.9627084092867692e-47
# gas model output 1 max 8.850791116157464e-12
# gas model output 2 =tau
# gas model output 3 max 8.850791116157464e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 8.850791116157464e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1410796.501776284
# dV min-1716197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0860779917910624e-11
# Knu shape (131, 180, 300)
# Knu mas 4.4290180820331376e-10
# tau first z slice max0.0
# arg first z slice max 7.5823338116306e-46
# gas model output 1 max 9.082599163884786e-12
# gas model output 2 =tau
# gas model output 3 max 9.082599163884786e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.082599163884786e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1442796.501776284
# dV min-1684197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0860845476940354e-11
# Knu shape (131, 180, 300)
# Knu mas 4.554145914008986e-10
# tau first z slice max0.0
# arg first z slice max 2.0048947114802192e-44
# gas model output 1 max 9.160387597337645e-12
# gas model output 2 =tau
# gas model output 3 max 9.160387597337646e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.160387597337645e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1474796.501776284
# dV min-1652197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086091103603905e-11
# Knu shape (131, 180, 300)
# Knu mas 4.5754013889602915e-10
# tau first z slice max0.0
# arg first z slice max 3.406729452141613e-44
# gas model output 1 max 9.328841424359833e-12
# gas model output 2 =tau
# gas model output 3 max 9.328841424359833e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.328841424359833e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1506796.501776284
# dV min-1620197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086097659520669e-11
# Knu shape (131, 180, 300)
# Knu mas 4.14350074714427e-10
# tau first z slice max0.0
# arg first z slice max 4.1613864905715156e-44
# gas model output 1 max 9.144235592985933e-12
# gas model output 2 =tau
# gas model output 3 max 9.144235592985933e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.144235592985933e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1538796.501776284
# dV min-1588197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0861042154443265e-11
# Knu shape (131, 180, 300)
# Knu mas 4.2040204750754475e-10
# tau first z slice max0.0
# arg first z slice max 4.862001738861542e-44
# gas model output 1 max 9.339488569306522e-12
# gas model output 2 =tau
# gas model output 3 max 9.339488569306524e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.339488569306522e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1570796.501776284
# dV min-1556197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0861107713748795e-11
# Knu shape (131, 180, 300)
# Knu mas 4.0168319069003877e-10
# tau first z slice max0.0
# arg first z slice max 5.624954936380166e-44
# gas model output 1 max 9.074577093816503e-12
# gas model output 2 =tau
# gas model output 3 max 9.074577093816505e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.074577093816503e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1602796.501776284
# dV min-1524197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086117327312328e-11
# Knu shape (131, 180, 300)
# Knu mas 4.198691413231577e-10
# tau first z slice max0.0
# arg first z slice max 5.129264594174271e-44
# gas model output 1 max 9.3043460438449e-12
# gas model output 2 =tau
# gas model output 3 max 9.304346043844902e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.3043460438449e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1634796.501776284
# dV min-1492197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0861238832566684e-11
# Knu shape (131, 180, 300)
# Knu mas 4.192422191005341e-10
# tau first z slice max0.0
# arg first z slice max 4.849956944364335e-44
# gas model output 1 max 9.096543123415397e-12
# gas model output 2 =tau
# gas model output 3 max 9.096543123415397e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.096543123415397e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1666796.501776284
# dV min-1460197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086130439207906e-11
# Knu shape (131, 180, 300)
# Knu mas 4.4990084206474376e-10
# tau first z slice max0.0
# arg first z slice max 4.3252245600350616e-44
# gas model output 1 max 9.264182791657106e-12
# gas model output 2 =tau
# gas model output 3 max 9.264182791657106e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.264182791657106e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1698796.501776284
# dV min-1428197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0861369951660386e-11
# Knu shape (131, 180, 300)
# Knu mas 4.385905590081246e-10
# tau first z slice max0.0
# arg first z slice max 3.435939281463536e-44
# gas model output 1 max 9.207560195620521e-12
# gas model output 2 =tau
# gas model output 3 max 9.207560195620521e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.207560195620521e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1730796.501776284
# dV min-1396197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086143551131063e-11
# Knu shape (131, 180, 300)
# Knu mas 4.417128249847998e-10
# tau first z slice max0.0
# arg first z slice max 8.458205407341557e-45
# gas model output 1 max 9.045546779939192e-12
# gas model output 2 =tau
# gas model output 3 max 9.04554677993919e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 9.045546779939192e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1762796.501776284
# dV min-1364197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.086150107102984e-11
# Knu shape (131, 180, 300)
# Knu mas 4.6043354009528116e-10
# tau first z slice max0.0
# arg first z slice max 6.888602653031104e-47
# gas model output 1 max 8.985460384969845e-12
# gas model output 2 =tau
# gas model output 3 max 8.985460384969847e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 8.985460384969845e-12
# disk.vel_phi shape (131, 180, 300)
# disk.vel_phi min 0.0
# disk.vel_phi max 3509050.46720099
# disk.vel_phi med 363394.5724524265
# los_vel shape (131, 180, 300)
# los_vel min -3141593.0035525686
# los_vel max 3112394.58434527
# los_vel med 0.0
# dV max1794796.501776284
# dV min-1332197.2921726347
# Signu shape (131, 180, 300)
# Signu max nan
# Snu shape (131, 180, 300)
# Snu mas 3.0861566630818e-11
# Knu shape (131, 180, 300)
# Knu mas 4.799988853412432e-10
# tau first z slice max0.0
# arg first z slice max 1.9855820541560548e-50
# gas model output 1 max 8.955639676612335e-12
# gas model output 2 =tau
# gas model output 3 max 8.955639676612335e-12
# S Shape (131, 180, 300)
# S min -2534997740081333.5
# Inu shape (131, 180)
# Inu max 8.955639676612335e-12
# cube max9.339488569306522e-12
# cube shape (131, 180, 15)
# X max1495978707000000.0
# Y max 1495541902281224.8
# X shape (131, 180)
# im max8.35095855172937e-12
# im shape (512, 512, 15)
# im2 max 8.35095855172937e-12
# im_s max 0.04907113142107233

# %%
# %run raytrace.py

# %%
total_model(y, modfile="85_incl_nospiral", distance=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fa3d6a5bca83> in <module>
# ----> 1 total_model(y, modfile="85_incl_nospiral", distance=30)
#
# NameError: name 'y' is not defined

# %%
'''I think... this should give surface density for every point in the disk in a 2d grid
after being perturbed.'''

def perturbed_sigma(grid_radius, grid_angle, p, rin, rout ,md, beta, m, alpha, pos):
    
    '''Spiral-perturbed surface density [msun / au^2]
    grid_radius = radial grid [au]
    grid_angle = azimuthal grid [-np.pi,np.pi] [rad]
    p = power law index of the density profile. \Sigma \propto r^(p)
    rin = inner radius of the disc [au]
    rout = outer radius of the disc [au]
    md = mass of the disc [msun]
    m = number of the spiral arms
    alpha = pitch angle of the spiral [rad]
    pos = angle of the spiral within the disc [rad]'''
    
    
    return   beta**(-1/2) * -np.cos(-(m * 
    grid_angle + m/np.tan(alpha) * -np.log(grid_radius) + pos))

# %%
#understanding structure of perturbed_sigma and how to use it
#Parameters
ms = 1 #star mass
md = 0.35 #disc mass
p = -.5 #surface density
ap = 60*np.pi/180 #pitch angle
m = 2 #azimuthal wavenumber
beta = 5 #cool
incl = np.pi/2.1 #inclination of the disc towards the line of sight
pos = 90 # rotation of spiral (degrees), starting north, cw

#1d r array
r = np.linspace(1,100,50)
#1d phi array
phi = np.linspace(-np.pi,np.pi,180)
#meshgrid but... why not use r array? And what is purpose of j? Indexing?
gr, gphi = np.mgrid[1:100:50j, -np.pi:np.pi:180j] #rin:rout:resolution
#print("gr shape " + str(gr.shape))
#print("gphi shape " + str(gphi.shape))
#print("gr" + str(gr))
#print("gphi" + str(gphi))
gx, gy = np.mgrid[-100:100:200j,-100:100:200j]
car = np.linspace(-100,100,200)
grid_angle = 0*gx
g_r = (gx**2+gy**2)**(0.5)
#print(str(gr.shape)+"gr shape")

for i in range(len(car)):
    for j in range(len(car)):
        grid_angle[i,j] = math.atan2(car[i], car[j])

#print(str(grid_angle.shape)+"grid_angle shape")
#print("grid_angle" + str(grid_angle[200,:]))
#print("g_r " + str(g_r[200,:]))
#print(str(gr.shape)+"gr shape")
spir0 = perturbed_sigma(g_r, grid_angle, p, 1, 100, md, beta, m, ap,0)
#print(spir0.shape)
spir1 = perturbed_sigma(g_r, grid_angle, p, 1, 100, md, beta, m, ap,30)
spir2 = perturbed_sigma(g_r, grid_angle, p, 1, 100, md, beta, m, ap,90)

# %%
gr, gphi = np.mgrid[1:100:50j, -np.pi:np.pi:180j]

def cart2pol(x, y):
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)

def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return(x, y)

# %%
x_grid_test, y_grid_test = pol2cart(gr, gphi)
#plt.scatter(x_grid_test, y_grid_test)
#plt.show()

#x_coord, y_coord = np.meshgrid(x_grid_test, y_grid_test)

#plt.imshow(x_coord)
#plt.colorbar()

# %%
plt.imshow(y_grid_test)

# %%
#x_coord, y_coord = np.meshgrid(x_grid_test, y_grid_test)

# %%
plt.imshow(g_r)

# %%
plt.imshow(grid_angle)
plt.colorbar()

# %%
#ok... but this is a square and not a disk.... and also what are the units here?? I'm guessing this has to be compared
#with some already existing global surface density...

plt.imshow(spir0)
plt.colorbar()
plt.show()
plt.imshow(spir1)
plt.colorbar()
plt.show()
plt.imshow(spir2)
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(g_r, grid_angle, c=spir2)
ax.set_xlabel("Radius (AU)")
ax.set_ylabel("Azimuth (radians)")
ax.set_title("Cartesian spiral plotted in R/Phi coordinates")
plt.colorbar()

# %%
for i in range(len(car)):
    for j in range(len(car)):
        if(g_r[i,j] > 100):
            spir2[i,j] = -np.inf

# %%
plt.imshow(spir2+1)
plt.colorbar()

# %%
radius = np.linspace(1, 50, 200)
phi = np.linspace(-3*np.pi, 3*np.pi, 600)

# %%
#bigger_phi = np.append(phi, phi + 2*np.pi)
#bigbig_phi = np.append(bigger_phi, -2)

# %%
rr, pp = np.meshgrid(radius, phi)

# %%
new_array = 0

# %%
grid_angle1d = np.ravel(grid_angle)

new_array = np.append(grid_angle1d, grid_angle1d+2*np.pi)
print(new_array)
last_array = np.append(new_array, grid_angle1d-2*np.pi)
# Out:
# [-2.35619449 -2.35114403 -2.34604255 ...  7.07873541  7.07363393
#   7.06858347]

# %%
flat_r = np.ravel(g_r)
g_r2 = np.append(flat_r, flat_r)
g_r3 = np.append(g_r2, flat_r)

flat_spir = np.ravel(spir2)
flat_spr2 = np.append(flat_spir, flat_spir)
flat_spr3 = np.append(flat_spr2, flat_spir)

# %%
#interp_test = interpnd((np.ravel(g_r), np.ravel(grid_angle)), np.ravel(spir2))
interp_test = interpnd((g_r3, last_array), flat_spr3)

# %%
z = interp_test(rr, pp)

# %%
z.shape
# Out:
# (600, 200)

# %%
#plt.imshow(z)

# %%
plt.scatter(rr, pp, c=z)

# %%
plt.imshow(z[200:400, :])
print(np.max(z[200:400, :]))
# Out:
# 0.4469095177826307

# %%
unpert_sigma = giggle.sigma(p, 1, 100, md, g_r)

# %%
spiral_sigma = spir2*unpert_sigma + unpert_sigma

for i in range(len(car)):
    for j in range(len(car)):
        if(g_r[i,j] > 100):
            spiral_sigma[i,j] = -np.inf

plt.imshow(spiral_sigma)
plt.colorbar()

# %%
 def set_structure(self):
        #tst=time.clock()
        '''Calculate the disk density and temperature structure given the specified parameters'''
        # Define the desired regular cylindrical (r,z) grid
        nac = 500#256             # - number of unique a rings
        #nrc = 256             # - numver of unique r points
        amin = self.Ain       # - minimum a [AU]
        amax = self.Aout      # - maximum a [AU]
        e = self.ecc          # - eccentricity
        nzc = int(2.5*nac)#nac*5           # - number of unique z points
        '''defining z-array: .1 AU to specified max value in AU. logarithmic. number specified by
        # of annuli'''
        zmin = .1*Disk.AU      # - minimum z [AU]
        nfc = self.nphi       # - number of unique f points
        af = np.logspace(np.log10(amin),np.log10(amax),nac)
        zf = np.logspace(np.log10(zmin),np.log10(self.zmax),nzc)

        #adding this to triple check z-dimension is doing what I think it is
        print("1d z-array " + str(zf))

        pf = np.linspace(0,2*np.pi,self.nphi) #f is with refrence to semi major axis
        ff = (pf - self.aop) % (2*np.pi) # phi values are offset by aop- refrence to sky
        rf = np.zeros((nac,nfc))
        for i in range(nac):
            for j in range(nfc):
                rf[i,j] = (af[i]*(1.-e*e))/(1.+e*np.cos(ff[j]))

        '''1d array of z-values as ones'''
        idz = np.ones(nzc)
        idf = np.ones(self.nphi)
        #rcf = np.outer(rf,idz)
        ida = np.ones(nac)
        ##zcf = np.outer(ida,zf)
        ##acf = af[:,np.newaxis]*np.ones(nzc)
        #order of dimensions: a, f, z
        '''meshgrid of z values above midplane'''
        pcf,acf,zcf = np.meshgrid(pf,af,zf)
        #zcf = (np.outer(ida,idf))[:,:,np.newaxis]*zf
        #pcf = (np.outer(ida,pf))[:,:,np.newaxis]*idz
        fcf = (pcf - self.aop) % (2*np.pi)
        #acf = (np.outer(af,idf))[:,:,np.newaxis]*idz
        
        '''should be 0 grid in shape of radius, phi, z above midplane'''
        rcf=rf[:,:,np.newaxis]*idz
        print(str(rcf.shape))
        #print("coords init {t}".format(t=time.clock()-tst))


        # Here introduce new z-grid (for now just leave old one in)

        # Interpolate dust temperature and density onto cylindrical grid
        ###### doesnt seem to be used anywhere ######


        # bundle the grid for helper functions
        ###### add angle to grid? ######
        '''nac, nfc, nzc are resolution (int) in each dimension. rcf is 0s grid in 3d. 
        amax is max a (AU), zcf is z meshgrid'''
        grid = {'nac':nac,'nfc':nfc,'nzc':nzc,'rcf':rcf,'amax':amax,'zcf':zcf}#'ff':ff,'af':af,
        self.grid=grid

        #print("grid {t}".format(t=time.clock()-tst))
        #define temperature structure
        # use Dartois (03) type II temperature structure
        ###### expanding to 3D should not affect this ######
        delta = 1.                # shape parameter
        rcf150=rcf/(150.*Disk.AU)
        rcf150q=rcf150**self.qq
        
        '''# zq0 = Zq, in AU, at 150 AU (????)'''
        '''zq should be 3d and scaled by 150 AU...???'''
        zq = self.zq0*Disk.AU*rcf150**1.3
        print("shape of zq " +str(zq.shape))
        print("zq " +str(zq))
    
        #zq = self.zq0*Disk.AU*(rcf/(150*Disk.AU))**1.1
        tmid = self.tmid0*rcf150q
        tatm = self.tatm0*rcf150q
        tempg = tatm + (tmid-tatm)*np.cos((np.pi/(2*zq))*zcf)**(2.*delta)

        '''ii is 3d boolean grid of z values above some critical value'''
        ii = zcf > zq
        tempg[ii] = tatm[ii]
        #Type I structure
#        tempg = tmid*np.exp(np.log(tatm/tmid)*zcf/zq)
        ###### this step is slow!!! ######

        # Calculate vertical density structure

        ## Circular:
        #Sc = self.McoG*(2.-self.pp)/(2*np.pi*self.Rc*self.Rc)
        #siggas = Sc*(rf/self.Rc)**(-1*self.pp)*np.exp(-1*(rf/self.Rc)**(2-self.pp))
        ## Elliptical:
        #asum = (np.power(af,-1*self.pp)).sum()
        rp1 = np.roll(rf,-1,axis=0)
        rm1 = np.roll(rf,1,axis=0)
        #*** Approximations used here ***#

        Sc = self.McoG*(2.-self.pp)/(self.Rc*self.Rc)
        siggas_r = Sc*(acf[:,:,0]/self.Rc)**(-1*self.pp)*np.exp(-1*(acf[:,:,0]/self.Rc)**(2-self.pp))

        dsdth = (acf[:,:,0]*(1-e*e)*np.sqrt(1+2*e*np.cos(fcf[:,:,0])+e*e))/(1+e*np.cos(fcf[:,:,0]))**2
        siggas = ((siggas_r*np.sqrt(1.-e*e))/(2*np.pi*acf[:,:,0]*np.sqrt(1+2*e*np.cos(fcf[:,:,0])+e*e)))*dsdth

        ## Add an extra ring
        if self.ring is not None:
            w = np.abs(rcf-self.Rring)<self.Wring/2.
            if w.sum()>0:
                tempg[w] = tempg[w]*(rcdf[w]/(150*Disk.AU))**(self.sig_enhance-self.qq)/((rcf[w].max())/(150.*Disk.AU))**(-self.qq+self.sig_enhance)


        self.calc_hydrostatic(tempg,siggas,grid)

        self.vel = np.sqrt(Disk.G*self.Mstar/(acf*(1-self.ecc**2.)))*(np.cos(self.aop+fcf)+self.ecc*self.cosaop)


        # Check for NANs
        ### nolonger use Omg ###
        #ii = np.isnan(Omg)
        #Omg[ii] = Omk[ii]
        ii = np.isnan(self.rho0)
        if ii.sum() > 0:
            self.rho0[ii] = 1e-60
            print('Beware: removed NaNs from density (#%s)' % ii.sum())
        ii = np.isnan(tempg)
        if ii.sum() > 0:
            tempg[ii] = 2.73
            print('Beware: removed NaNs from temperature (#%s)' % ii.sum())

        #print("nan chekc {t}".format(t=time.clock()-tst))
        # find photodissociation boundary layer from top
        zpht_up = np.zeros((nac,nfc))
        zpht_low = np.zeros((nac,nfc))
        sig_col = np.zeros((nac,nfc,nzc))
        #zice = np.zeros((nac,nfc))
        for ia in range(nac):
            for jf in range (nfc):
                psl = (Disk.Hnuctog/Disk.m0*self.rho0[ia,jf,:])[::-1]
                zsl = self.zmax - (zcf[ia,jf,:])[::-1]
                foo = (zsl-np.roll(zsl,1))*(psl+np.roll(psl,1))/2.
                foo[0] = 0
                nsl = foo.cumsum()
                sig_col[ia,jf,:] = nsl[::-1]*Disk.m0/Disk.Hnuctog
                pht = (np.abs(nsl) >= self.sigbound[0])
                if pht.sum() == 0:
                    zpht_up[ia,jf] = np.min(self.zmax-zsl)
                else:
                    zpht_up[ia,jf] = np.max(self.zmax-zsl[pht])
                #Height of lower column density boundary
                pht = (np.abs(nsl) >= self.sigbound[1])
                if pht.sum() == 0:
                    zpht_low[ia,jf] = np.min(self.zmax-zsl)
                else:
                    zpht_low[ia,jf] = np.max(self.zmax-zsl[pht])
                #used to be a seperate loop
                ###### only used for plotting
                #foo = (tempg[ia,jf,:] < Disk.Tco)
                #if foo.sum() > 0:
                #    zice[ia,jf] = np.max(zcf[ia,jf,foo])
                #else:
                #    zice[ia,jf] = zmin
        self.sig_col = sig_col
        #szpht = zpht
        #print("Zpht {t} seconds".format(t=(time.clock()-tst)))
        self.af = af
        #self.ff = ff
        #self.rf = rf
        self.pf = pf
        self.nac = nac
        self.zf = zf
        self.nzc = nzc
        self.tempg = tempg
        #self.Omg0 = Omg#velrot
        self.zpht_up = zpht_up
        self.zpht_low = zpht_low
        self.pcf = pcf  #only used for plotting can remove after testing
        self.rcf = rcf  #only used for plotting can remove after testing

# %%
#x=disk.Disk()

# %%
#%run raytrace.py
#total_model(x)

# %%
#y=kevindisk.Disk()

# %%
#%run raytrace.py
#total_model(y)

# %%
nac = 500#256             # - number of unique a rings
#nrc = 256             # - numver of unique r points
amin = 1       # - minimum a [AU]
amax = 100      # - maximum a [AU]
e = 0          # - eccentricity
nzc = int(2.5*nac)#nac*5           # - number of unique z points
'''defining z-array: .1 AU to specified max value in AU. logarithmic. number specified by
# of annuli'''
zmin = .1      # - minimum z [AU]
nfc = 180      # - number of unique f points
af = np.logspace(np.log10(amin),np.log10(amax),nac)
zf = np.logspace(np.log10(zmin),np.log10(10),nzc)

#adding this to triple check z-dimension is doing what I think it is
#print("1d z-array " + str(zf))

pf = np.linspace(0,2*np.pi,180) #f is with refrence to semi major axis
ff = (pf - 0) % (2*np.pi) # phi values are offset by aop- refrence to sky
rf = np.zeros((nac,nfc))
for i in range(nac):
    for j in range(nfc):
        rf[i,j] = (af[i]*(1.-e*e))/(1.+e*np.cos(ff[j]))

'''1d array of z-values as ones'''
idz = np.ones(nzc)
idf = np.ones(180)
#rcf = np.outer(rf,idz)
ida = np.ones(nac)
##zcf = np.outer(ida,zf)
##acf = af[:,np.newaxis]*np.ones(nzc)
#order of dimensions: a, f, z
'''meshgrid of z values above midplane'''
pcf,acf,zcf = np.meshgrid(pf,af,zf)
#zcf = (np.outer(ida,idf))[:,:,np.newaxis]*zf
#pcf = (np.outer(ida,pf))[:,:,np.newaxis]*idz
fcf = (pcf - 0) % (2*np.pi)
#acf = (np.outer(af,idf))[:,:,np.newaxis]*idz

'''should be 0 grid in shape of radius, phi, z above midplane'''
rcf=rf[:,:,np.newaxis]*idz

# %%
#r = np.linspace(1, 10, 50)
#p = np.linspace(0, np.pi*2, 180)
r_grid, phi_grid = np.meshgrid(r,p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-89be7573c249> in <module>
#       1 #r = np.linspace(1, 10, 50)
#       2 #p = np.linspace(0, np.pi*2, 180)
# ----> 3 r_grid, phi_grid = np.meshgrid(r,p)
#
# NameError: name 'r' is not defined

# %%
ap = 30*np.pi/180 #pitch angle

#understanding structure of perturbed_sigma and how to use it
#Parameters
ms = 1 #star mass
md = 0.35 #disc mass
p = -.5 #surface density
ap = 30*np.pi/180 #pitch angle
m = 2 #azimuthal wavenumber
beta = 5 #cool
incl = np.pi/6 #inclination of the disc towards the line of sight
pos = 90 # rotation of spiral (degrees), starting north, cw

gx, gy = np.mgrid[-100:100:100j,-100:100:100j]
grid_radius = np.sqrt(gx**2 + gy**2)

uphC_test = giggle.uphC(gx, gy, ms, md, p, m, 1, beta, 10, 100, ap, 0)

# %%
plt.imshow(np.log10(uphC_test))
plt.colorbar()

# %%
urC_test = giggle.urC(gx, gy, ms, md, p, m, 1, beta, 10, 100, ap, 0)

# %%
plt.imshow(urC_test)

# %%
gr_vel, gphi_vel = cart2pol(gx, gy)

# %%
urC_test.shape
# Out:
# (100, 100)

# %%
plt.scatter(gr_vel, gphi_vel, c=urC_test)

# %%
interp_test_rad = interpnd((np.ravel(gr_vel), np.ravel(gphi_vel)), np.ravel(urC_test))

# %%
vel_r = interp_test_rad(rr, pp)

# %%
vel_r.shape
# Out:
# (200, 200)

# %%
plt.scatter(rr, pp, c=vel_r)
plt.colorbar()

# %%
nanmask = np.isnan(vel_r)
vel_r[nanmask] = 0

# %%
plt.scatter(rr, pp,c=vel_r)
plt.colorbar()

# %%
plt.imshow(vel_r)

# %%
interp_test_phi = interpnd((np.ravel(gr_vel), np.ravel(gphi_vel)), np.ravel(uphC_test))

# %%
vel_phi = interp_test_phi(rr, pp)

# %%
plt.scatter(rr, pp, c=vel_phi)
plt.colorbar()

# %%
def keplerian(ms, r):
    v = np.sqrt(G*(ms * u.M_sun.to(u.kg) /(r*u.AU.to(u.meter))))
    return v

# %%
kep_test = keplerian(1, np.linspace(1, 10, 10))

# %%
kep_test
# Out:
# <Quantity [29784.69182968, 21060.95756832, 17196.19984559, 14892.34591484,
#            13320.11912401, 12159.54952146, 11257.55535115, 10530.47878416,
#             9928.23060989,  9418.7465588 ] m(3/2) / (kg(1/2) s)>

# %%
plt.plot(np.linspace(1, 100, 10), keplerian(1, np.linspace(1, 100, 10)))

# %%
phi_nan_mask = np.isnan(vel_phi)
#rr[phi_nan_mask]
phi_nan_kep = keplerian(ms, rr[phi_nan_mask])/1000
vel_phi[phi_nan_mask] = phi_nan_kep

plt.imshow(np.log10(vel_phi))
plt.colorbar()

# %%
gx, gy = np.mgrid[-100:100:400j,-100:100:400j]
g_r, g_phi = cart2pol(gx, gy)
car = np.linspace(-100,100,400)
grid_angle = 0*gx
#g_r = (gx**2+gy**2)**(0.5)
#print(str(gr.shape)+"gr shape")

#print(str(grid_angle.shape)+"grid_angle shape")
#print(str(gr.shape)+"gr shape")
spir0 = giggle.perturbed_sigma(g_r, g_phi, p, 1, 100, md, beta, m, ap,0)

#plt.imshow(spir0)
#plt.savefig("cart_spir_surf.png")
#plt.show()


#plt.scatter(g_r, g_phi, c=spir0)
#plt.savefig("spiral_b4_interp_surf.png")
#plt.show()



interp_test = interpnd((np.ravel(g_r), np.ravel(g_phi)), np.ravel(spir0))
siggas = interp_test(acf[:,:,0], pcf[:,:,0]-np.pi)

# %%
siggas
# Out:
# array([[       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan, 0.44378046, 0.44645864, ..., 0.42397763, 0.43252378,
#                nan],
#        [       nan, 0.44230061, 0.44501505, ..., 0.41863153, 0.4289849 ,
#                nan],
#        [       nan, 0.43914888, 0.44355217, ..., 0.41333056, 0.42403142,
#                nan]])

# %%
plt.imshow(siggas)

# %%
plt.scatter(acf[:,:,0], pcf[:,:,0]-np.pi, c=siggas)

# %%
x, y = pol2cart(acf[:,:,0], pcf[:,:,0])

# %%
plt.scatter(x, y, c=siggas)

# %%
from astropy.io import fits
fits.info('40degincl.fits')
# Out:
# Filename: 40degincl.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (512, 512, 15)   float64

# %%
hdul = fits.open('40degincl.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(2-1) in Hz

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  512
# NAXIS2  =                  512
# NAXIS3  =                   15
# CDELT1  = -1.3888888888888E-05
# CRPIX1  =                256.5
# CRVAL1  =                  0.0
# CTYPE1  = 'RA---SIN'
# CDELT2  = 1.38888888888888E-05
# CRPIX2  =                256.5
# CRVAL2  =                  0.0
# CTYPE2  = 'DEC--SIN'
# CTYPE3  = 'VELO-LSR'
# CDELT3  =                320.0
# CRPIX3  =                    1
# CRVAL3  =               3550.0
# OBJECT  = 'model   '
# EPOCH   =               2000.0
# RESTFRQ =       345795989900.0

# %%
hdul.close()

# %%
hdul = fits.open('direct_vel_ampadj.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('sameparams_sigma-and-vel.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('kevincodetest.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('unedited_dd_disk.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('xy_arctanflip.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

# %%
hdul = fits.open('longarini_copy.fits', mode='update')
hdul[0].header['RESTFRQ'] = 345.7959899e9  # # Example: CO(3-2) in Hz
hdul.flush()
hdul.close()

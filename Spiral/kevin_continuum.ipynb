# %%
import disk as kevindisk
import disk_ecc

# %%
disk = kevindisk.Disk()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk.py:209: RuntimeWarning: invalid value encountered in sqrt
#   Omg = np.sqrt((dPdr/(rcf*self.rho0)+Disk.G*self.Mstar/(rcf**2+zcf**2)**1.5))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   theta_crit = np.arctan((self.Rout+tdiskY)/(self.zmax-tdiskZ))

# %%
# %run raytrace.py

# %%
disk.plot_structure()
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk.py:624: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10((self.rhoG/self.Xmol)[0,:,:]),np.arange(0,11,0.1))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk.py:626: RuntimeWarning: divide by zero encountered in log10
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.sig_col[0,:,:]),(-2,-1),linestyles=':',linewidths=3,colors='k')
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk.py:626: RuntimeWarning: invalid value encountered in log10
#   cs3 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.sig_col[0,:,:]),(-2,-1),linestyles=':',linewidths=3,colors='k')

# %%
total_model(disk, modfile="cont_test", isgas=False, includeDust=True, flipme=False)
# Out:
# cube max0.0
# cube shape (131, 180, 15)
# X max1.495978707e+16
# Y max 1.4955419022812248e+16
# X shape (131, 180)
# im max0.0
# im shape (512, 512, 15)
# im_s max0.0
# im_s shape (512, 512, 15)

# %%
disk = disk_ecc.Disk()
# Out:
# 1d z-array [1.49597871e+12 3.53094094e+12 5.56590316e+12 ... 2.53909388e+15
#  2.54112884e+15 2.54316380e+15]
# (500, 131, 1250)
# siggas[[8.81923659e-02 8.81923659e-02 8.81923659e-02 ... 8.81923659e-02
#   8.81923659e-02 8.81923659e-02]
#  [7.26250057e-02 7.26250057e-02 7.26250057e-02 ... 7.26250057e-02
#   7.26250057e-02 7.26250057e-02]
#  [6.14908377e-02 6.14908377e-02 6.14908377e-02 ... 6.14908377e-02
#   6.14908377e-02 6.14908377e-02]
#  ...
#  [1.23680845e-06 1.23680845e-06 1.23680845e-06 ... 1.23680845e-06
#   1.23680845e-06 1.23680845e-06]
#  [1.21813121e-06 1.21813121e-06 1.21813121e-06 ... 1.21813121e-06
#   1.21813121e-06 1.21813121e-06]
#  [1.19974076e-06 1.19974076e-06 1.19974076e-06 ... 1.19974076e-06
#   1.19974076e-06 1.19974076e-06]]
# ...

# %%
disk.plot_structure()
# Out:
# self.Z shape (131, 180, 300)
# self.Z[0,:,:] shape (180, 300)
# z[0,:,:,] contents [[ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  ...
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]
#  [ 2.54316380e+15  2.52620938e+15  2.50925495e+15 ... -2.49230053e+15
#   -2.50925495e+15 -2.52620938e+15]]
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:1000: RuntimeWarning: divide by zero encountered in log10
#   cs2 = plt.contour(self.r[0,:,:]/Disk.AU,self.Z[0,:,:]/Disk.AU,np.log10(self.rhoG[0,:,:])+4,np.arange(0,11,0.1))
# ...

# %%
total_model(disk, modfile="contdisk_ecc_test", isgas=False, includeDust=True, flipme=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c2f327eb9488> in <module>
# ----> 1 total_model(disk, modfile="contdisk_ecc_test", isgas=False, includeDust=True, flipme=False)
#
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace.py in total_model(disk, imres, distance, chanmin, nchans, chanstep, flipme, Jnum, freq0, xnpix, vsys, PA, offs, modfile, abund, obsv, wind, isgas, includeDust, extra, bin, hanning, L_cloud, tau, sigma_c, velocity_c, manual_chan_params, response_function)
#     427             cube3[:,:,:,i] = tau_dust
#     428         else:
# --> 429             Inu,tau_dust = dustmodel(disk,freq0)
#     430             cube[:,:,i] = Inu
#     431             cube2[:,:,:,i] = tau_dust
#
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/raytrace.py in dustmodel(disk, nu)
#     176
#     177     # - Define some arrays, sizes and useful constants
# ...

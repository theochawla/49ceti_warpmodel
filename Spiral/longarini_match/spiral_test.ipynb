# %%
import giggle_my_version as giggle
import numpy as np 
import matplotlib.pyplot as plt

import math
#from scipy import ndimage as ndimage
import disk_ecc_spiral_gauss as disk
#import disk_ecc_spiral as disk_nogauss
#import disk as original
#import disk_ecc as disk_ecc

#import disk_ecc as kevindisk
#import disk_ecc_spiral_pp as proto
#from astropy import units as u
#from astropy.constants import G, sigma_sb, k_B, m_p

#from scipy.interpolate import LinearNDInterpolator as interpnd

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
for_sd = disk.Disk(Aout=100.,incl=30, Mstar=1, Ain=1, proto=False, md=0.2, ap=15, m=2,  surf_amp=0.45)
# Out:
# g_phi max3.140341089787712
# g_phi min-3.140341089787712
# tempg shape (500, 131, 1250)
# zcf shape (500, 131, 1250)
# sigint shape (500, 131)
# 7.023055245989484e-15
# phi_flat-vel length640000
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk_ecc_spiral.py:828: RuntimeWarning: divide by zero encountered in divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))
# tempg max 219.14584184966867

# %%
# %run raytrace_spiral.py

# %%
total_model(x, modfile="hydro_test", distance=30, flipme=False)

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
no_gauss = disk_nogauss.Disk(Aout=300.,incl=80, Mstar=2, Ain=15, proto=True, md=1e-4, ap=30, m=2, p=-2, Rc=50, surf_amp=0.25, sigbound=[1e-3,np.inf], Tmid0=14, zmax=30, McoG=1e-4)
# Out:
# g_phi max3.140341089787712
# g_phi min-3.140341089787712
# tempg shape (500, 131, 1250)
# zcf shape (500, 131, 1250)
# sigint shape (500, 131)
# 7.023055245989484e-15
# phi_flat-vel length640000
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk_ecc_spiral.py:828: RuntimeWarning: divide by zero encountered in divide
#   theta_crit = np.arctan((self.Aout*(1+self.ecc)+tdiskY)/(self.zmax-tdiskZ))
# tempg max 219.14584184966867

# %%
total_model(no_gauss, modfile="no_gauss", distance=30, flipme=False)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace_spiral.py:443: RuntimeWarning: divide by zero encountered in divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace_spiral.py:138: RuntimeWarning: divide by zero encountered in divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace_spiral.py:138: RuntimeWarning: invalid value encountered in divide
#   Signu = SignuF1*np.exp(-dV**2/disk.dBV**2)/disk.dBV*(1.-np.exp(-(BBF2*nu)/disk.T))   # - absorbing cross section
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace_spiral.py:156: RuntimeWarning: divide by zero encountered in divide
#   Snu = BBF1*nu**3/(np.exp((BBF2*nu)/disk.T)-1.) # - source function

# %%
'''testing disk model'''

#x = disk.Disk(zmax=10)
#testing with elias disk parameters to match logarini

'''testing with params of longarini 2021 moment 1 map
leaving default pp temp structure. Need to check on surface density definition and crit radius def'''
#x = disk.Disk(Tmid0=14, Rc=50., sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=1000.,incl=30.)
y = original.Disk(Rout=100.,incl=30, Mstar=1, Rin=1)
# Out:
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk.py:212: RuntimeWarning: divide by zero encountered in divide
#   Omg = np.sqrt((dPdr/(rcf*self.rho0)+Disk.G*self.Mstar/(rcf**2+zcf**2)**1.5))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk.py:212: RuntimeWarning: invalid value encountered in divide
#   Omg = np.sqrt((dPdr/(rcf*self.rho0)+Disk.G*self.Mstar/(rcf**2+zcf**2)**1.5))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk.py:212: RuntimeWarning: invalid value encountered in sqrt
#   Omg = np.sqrt((dPdr/(rcf*self.rho0)+Disk.G*self.Mstar/(rcf**2+zcf**2)**1.5))
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/disk.py:324: RuntimeWarning: divide by zero encountered in divide
#   theta_crit = np.arctan((self.Rout+tdiskY)/(self.zmax-tdiskZ))

# %%
# %run raytrace.py

# %%
total_model(x, modfile="disk_test", distance=30)
# Out:
# With mirroring on, chanmin has been reset to put the line center in central channel
# chanstep, nchans, chanmin: 0.320, 15.000, -2.240
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace.py:357: RuntimeWarning: divide by zero encountered in divide
#   tnl = gl*abund*disk.rhoG*np.exp(-(El/kB)/disk.T)/parZ
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 total_model(x, modfile="disk_test", distance=30)
#
# File /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace.py:375, in total_model(disk, imres, distance, chanmin, nchans, chanstep, flipme, Jnum, freq0, xnpix, vsys, PA, offs, modfile, abund, obsv, wind, isgas, includeDust, extra, bin, hanning, L_cloud, tau, sigma_c, velocity_c, manual_chan_params, response_function)
#     373 obs[6] = chans[i]  # - vsys
#     374 if isgas:
# --> 375     Inu,Inuz,tau_dust = gasmodel(disk,params,obs,moldat,tnl,wind,includeDust=includeDust)
#     376 #Inu_dust,tau_dust = dustmodel(disk,freq0)
#     377     cube[:,:,i] = Inu
#
# File /Volumes/disks/theo/49ceti_warpmodel/Spiral/gauss_apprx_spiral/raytrace.py:82, in gasmodel(disk, params, obs, moldat, tnl, wind, includeDust)
#      79     dV = veloc + (handed*np.sin(thet)*disk.Omg*disk.X[:,:,np.newaxis]*np.ones(nz))
#      80 else:
#      81     #Eccentric models do not have disk.Omg, but use disk.vel instead
# ---> 82     dV = veloc + handed*np.sin(thet)*(disk.vel)
#      85 if wind:
#      86     # add a 'wind'
#      87     vwind = np.cos(thet)*0.0*disk.cs*sign(disk.Z)
#
# AttributeError: 'Disk' object has no attribute 'vel'

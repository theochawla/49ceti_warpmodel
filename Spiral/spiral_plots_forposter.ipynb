# %%
import scipy

# %%
scipy.__version__
# Out:
# '1.16.2'

# %%
import bettermoments as bm
import numpy as np
import matplotlib.pyplot as plt
#import raytrace as ray
#import raytrace_spiral as ray_spir
import disk_ecc
import disk_ecc_spiral
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       4 #import raytrace as ray
#       5 #import raytrace_spiral as ray_spir
# ----> 6 import disk_ecc
#       7 import disk_ecc_spiral
#
# File /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc.py:20
#      18 from astropy import constants as const
#      19 from scipy.special import ellipk,ellipe
# ---> 20 from scipy.integrate import trapz
#      22 #testing time
#      23 import time
#
# ImportError: cannot import name 'trapz' from 'scipy.integrate' (/Users/tchawla/.local/lib/python3.13/site-packages/scipy/integrate/__init__.py)

# %%
#ceti_like_kep = disk_ecc.Disk(Tmid0=12, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=310.,Ain=73, incl=79.4)

# %%
#%run raytrace.py
#total_model(ceti_like_kep,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=-71.4,offs=[0.0,0.0],
                #modfile='poster_plots/ceti_like_kep',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                #L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)

# %%
ceti_like_spiral = disk_ecc_spiral.Disk(proto=False, md=.3, beta=5, ap=15, m=2, p=-1, Rc=125.1, Tmid0=9.37, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=310.,Ain=73, incl=79.4, vel_amp=4, surf_amp=1)
# Out:
# g_phi max6.281933743377506
# g_phi min0.0012515638020809128
# g_r_tiled.shape (1920000,)
# g_phi_tiled.shape (1920000,)
# tile max 12.565119050557092
# tile min 6.284436870981667
# spir_tiled.shape (1920000,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-46c32a34cc7e> in <module>
# ----> 1 ceti_like_spiral = disk_ecc_spiral.Disk(proto=False, md=.3, beta=5, ap=15, m=2, p=-1, Rc=125.1, Tmid0=9.37, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=310.,Ain=73, incl=79.4, vel_amp=4, surf_amp=1)
#
# /Volumes/disks/theo/49ceti_warpmodel/Spiral/disk_ecc_spiral.py in __init__(self, q, McoG, pp, Ain, Aout, Rc, incl, Mstar, Xco, vturb, Zq0, Tmid0, Tatm0, handed, ecc, aop, sigbound, Rabund, nr, nphi, nz, zmax, rtg, vcs, line, ring, md, p, ap, m, beta, pos, vel_amp, surf_amp, proto)
#      86         self.set_params(params) # set the structure parameters
#      87
# ...

# %%
# %run raytrace_spiral.py
total_model(ceti_like_spiral,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=-71.4,offs=[0.0,0.0],
                modfile='../poster_plots/ceti_like_spiral_velamp4',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# cube.shape (131, 180, 15)
# disk.X shape (131, 180)
# disk.Y shape (131, 180)
# disk.X shape (131, 180)
# rhoG max 2538.380407436518
# rhoG shape (131, 180, 300)
# tnl [[[3.39330285e-17 3.37565969e-17 3.37054758e-17 ... 3.34503337e-17
#    3.33645978e-17 3.33428684e-17]
#   [3.40869796e-17 3.38740788e-17 3.37915080e-17 ... 3.34692183e-17
#    3.33743561e-17 3.33557378e-17]
#   [3.43141950e-17 3.40583683e-17 3.39373628e-17 ... 3.35474184e-17
#    3.34459909e-17 3.34315974e-17]
#   ...
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]
#   [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#    0.00000000e+00 0.00000000e+00]]
#
#  [[3.39330285e-17 3.37565969e-17 3.37054758e-17 ... 3.34503337e-17
#    3.33645978e-17 3.33428684e-17]
#   [3.40262690e-17 3.23144650e-17 3.22266796e-17 ... 3.51072770e-17
# ...

# %%
faceon_kep = disk_ecc.Disk(Rc=125.1, Tmid0=9.37, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=310.,Ain=73, incl=30)
# Out:
# 1d z-array [1.49597871e+12 1.85410331e+12 2.21222792e+12 ... 4.48077363e+14
#  4.48435487e+14 4.48793612e+14]
# (500, 131, 1250)
# siggas[[0.00863913 0.00863913 0.00863913 ... 0.00863913 0.00863913 0.00863913]
#  [0.00855076 0.00855076 0.00855076 ... 0.00855076 0.00855076 0.00855076]
#  [0.00846364 0.00846364 0.00846364 ... 0.00846364 0.00846364 0.00846364]
#  ...
#  [0.00030924 0.00030924 0.00030924 ... 0.00030924 0.00030924 0.00030924]
#  [0.0003076  0.0003076  0.0003076  ... 0.0003076  0.0003076  0.0003076 ]
#  [0.00030596 0.00030596 0.00030596 ... 0.00030596 0.00030596 0.00030596]]
# self.vel min -528683.3082386631
# self.vel max528683.3082386631
# self.vel mean 2637.8449855202102
# R min0.0
# R max4637533991700000.0
# phi min0.0
# phi max6.283185307179586
# zind min 0.0
# zind max 1249.0
# zind mean 995.4374579194134
# phiind min 0.0
# phiind max 130.0
# phiind mean 65.02065013442005
# aind min 0.0
# aind max 500.0
# aind mean 171.51739131389272
# ...

# %%
# %run raytrace.py
total_model(faceon_kep,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=-71.4,offs=[0.0,0.0],
                modfile='poster_plots/faceon_kep',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# rhoG max 1769.7289973804122
# rhoG shape (131, 180, 300)
# Inu shape (131, 180)
# Inu max 1.707872251779499e-13
# Inu shape (131, 180)
# Inu max 1.7036916388823887e-13
# Inu shape (131, 180)
# Inu max 3.011990221354715e-13
# Inu shape (131, 180)
# Inu max 4.860876494061359e-13
# Inu shape (131, 180)
# Inu max 5.465670414496594e-13
# Inu shape (131, 180)
# Inu max 4.671377764006885e-13
# Inu shape (131, 180)
# Inu max 3.361326114200534e-13
# Inu shape (131, 180)
# Inu max 2.661094251607822e-13
# Inu shape (131, 180)
# Inu max 3.361324342478163e-13
# Inu shape (131, 180)
# Inu max 4.671368752060654e-13
# Inu shape (131, 180)
# Inu max 5.465653047798728e-13
# Inu shape (131, 180)
# Inu max 4.860854491530384e-13
# Inu shape (131, 180)
# Inu max 3.011976554974453e-13
# Inu shape (131, 180)
# Inu max 1.7037148697645072e-13
# Inu shape (131, 180)
# Inu max 1.7078996529915625e-13
# cube max5.465670414496594e-13
# cube shape (131, 180, 15)
# X max4637533991700000.0
# Y max 4636179897071797.0
# ...

# %%
faceon_spiral = disk_ecc_spiral.Disk(proto=False, md=.3, beta=5, ap=15, m=2, p=-1, Rc=125.1, Tmid0=9.37, sigbound=[1e-3,np.inf],zmax=30, McoG=1e-4, Aout=310.,Ain=73, incl=30)
# Out:
# g_phi max6.281933743377506
# g_phi min0.0012515638020809128
# g_r_tiled.shape (1920000,)
# g_phi_tiled.shape (1920000,)
# tile max 12.565119050557092
# tile min 6.284436870981667
# spir_tiled.shape (1920000,)
# phi_vel shape (800, 800)
# phi_flat-vel length640000

# %%
# %run raytrace.py
total_model(faceon_kep,imres=0.05,distance=30.,chanmin=-2.24,nchans=15,chanstep=0.32,flipme=False,Jnum=2,freq0=345.79599,xnpix=512,vsys=5.79,PA=-71.4,offs=[0.0,0.0],
                modfile='poster_plots/faceon_spiral',abund=1.,obsv=None,wind=False,isgas=True,includeDust=False,extra=0,bin=1,hanning=False,
                L_cloud=False, tau = [0,], sigma_c = [6,], velocity_c =[2,],manual_chan_params=False,response_function=False)
# Out:
# rhoG max 1769.7289973804122
# rhoG shape (131, 180, 300)
# Inu shape (131, 180)
# Inu max 1.707872251779499e-13
# Inu shape (131, 180)
# Inu max 1.7036916388823887e-13
# Inu shape (131, 180)
# Inu max 3.011990221354715e-13
# Inu shape (131, 180)
# Inu max 4.860876494061359e-13
# Inu shape (131, 180)
# Inu max 5.465670414496594e-13
# Inu shape (131, 180)
# Inu max 4.671377764006885e-13
# Inu shape (131, 180)
# Inu max 3.361326114200534e-13
# Inu shape (131, 180)
# Inu max 2.661094251607822e-13
# Inu shape (131, 180)
# Inu max 3.361324342478163e-13
# Inu shape (131, 180)
# Inu max 4.671368752060654e-13
# Inu shape (131, 180)
# Inu max 5.465653047798728e-13
# Inu shape (131, 180)
# Inu max 4.860854491530384e-13
# Inu shape (131, 180)
# Inu max 3.011976554974453e-13
# Inu shape (131, 180)
# Inu max 1.7037148697645072e-13
# Inu shape (131, 180)
# Inu max 1.7078996529915625e-13
# cube max5.465670414496594e-13
# cube shape (131, 180, 15)
# X max4637533991700000.0
# Y max 4636179897071797.0
# ...

# %%
rms=bm.estimate_RMS(data=data, N=1)
path = 'poster_plots/ceti_like_kep.fits'
hdul = fits.open(path, mode='update')
hdul[0].header['BUNIT'] = "Jy" 
hdul.flush()
hdul.close()

data, velax = bm.load_cube(path)
moments = bm.collapse_first(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=moments, method='first', path=path)

# %%
rms=1e-9
path = 'poster_plots/ceti_like_spiral.fits'
hdul = fits.open(path, mode='update')
hdul[0].header['BUNIT'] = "Jy" 
hdul.flush()
hdul.close()

data, velax = bm.load_cube(path)
moments = bm.collapse_ninth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=moments, method='ninth', path=path)

# %%
rms=1e-9
path = 'poster_plots/faceon_kep.fits'
hdul = fits.open(path, mode='update')
hdul[0].header['BUNIT'] = "Jy" 
hdul.flush()
hdul.close()

data, velax = bm.load_cube(path)
moments = bm.collapse_ninth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=moments, method='ninth', path=path)

# %%
rms=1e-9
path = 'poster_plots/faceon_spiral.fits'
hdul = fits.open(path, mode='update')
hdul[0].header['BUNIT'] = "Jy" 
hdul.flush()
hdul.close()

data, velax = bm.load_cube(path)
moments = bm.collapse_ninth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=moments, method='ninth', path=path)

# %%
rms=1e-9
path = 'poster_plots/faceon_spiral.fits'
hdul = fits.open(path, mode='update')
hdul[0].header['BUNIT'] = "Jy" 
hdul.flush()
hdul.close()

data, velax = bm.load_cube(path)
moments = bm.collapse_ninth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=moments, method='ninth', path=path)

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
import bettermoments as bm
import astropy.units as u
from astropy.wcs import WCS
from astropy.wcs.utils import proj_plane_pixel_scales

import numpy as np
from matplotlib.offsetbox import AnchoredOffsetbox, AuxTransformBox
from matplotlib.patches import Ellipse
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar

import astropy.units as u
from astropy.wcs.utils import proj_plane_pixel_scales
import cmcrameri.cm as cmc

#from astropy.visualization import wcsaxes

# %%
lb = fits.open('LB.uvfits')
lb_data = lb[0].data

# %%
lb[0].header
# Out:
# SIMPLE  =                    T /Standard FITS format
# BITPIX  =                  -32 /Floating point values
# NAXIS   =                    7
# NAXIS1  =                    0 /Random groups, NOT image
# NAXIS2  =                    3
# NAXIS3  =                    2
# NAXIS4  =                   30
# NAXIS5  =                    1
# NAXIS6  =                    1
# NAXIS7  =                    1
# EXTEND  =                    T /Tables may follow
# BLOCKED =                    T /File may be blocked
# GROUPS  =                    T /Random Group UV data
# PCOUNT  =                    9 /Number of random parameters
# GCOUNT  =                37926 /Number of groups (rows) in the file
#
# EPOCH   =   2.000000000000E+03
# BSCALE  =   1.000000000000E+00
# BZERO   =   0.000000000000E+00
# BUNIT   = 'UNCALIB '
# CTYPE2  = 'COMPLEX '
# CRVAL2  =   1.000000000000E+00
# CDELT2  =   1.000000000000E+00
# CRPIX2  =   1.000000000000E+00
# CROTA2  =   0.000000000000E+00
# CTYPE3  = 'STOKES  '
# CRVAL3  =  -5.000000000000E+00
# CDELT3  =  -1.000000000000E+00
# CRPIX3  =   1.000000000000E+00
# CROTA3  =   0.000000000000E+00
# CTYPE4  = 'FREQ    '
# CRVAL4  =   3.457930127693E+11
# CDELT4  =   9.766848588867E+05
# CRPIX4  =   1.600000000000E+01
# CROTA4  =   0.000000000000E+00
# CTYPE5  = 'IF      '
# CRVAL5  =   1.000000000000E+00
# CDELT5  =   1.000000000000E+00
# CRPIX5  =   1.000000000000E+00
# CROTA5  =   0.000000000000E+00
# CTYPE6  = 'RA      '
# CRVAL6  =   0.000000000000E+00
# CDELT6  =   1.000000000000E+00
# CRPIX6  =   1.000000000000E+00
# CROTA6  =   0.000000000000E+00
# CTYPE7  = 'DEC     '
# CRVAL7  =   0.000000000000E+00
# CDELT7  =   1.000000000000E+00
# CRPIX7  =   1.000000000000E+00
# CROTA7  =   0.000000000000E+00
# PTYPE1  = 'UU      '
# PSCAL1  =   1.000000000000E+00
# PZERO1  =   0.000000000000E+00
# PTYPE2  = 'VV      '
# PSCAL2  =   1.000000000000E+00
# PZERO2  =   0.000000000000E+00
# PTYPE3  = 'WW      '
# PSCAL3  =   1.000000000000E+00
# PZERO3  =   0.000000000000E+00
# PTYPE4  = 'DATE    '           /Day number
# PSCAL4  =   1.000000000000E+00
# PZERO4  =   0.000000000000E+00
# PTYPE5  = 'DATE    '           /Day fraction
# PSCAL5  =   1.000000000000E+00
# PZERO5  =   0.000000000000E+00
# PTYPE6  = 'BASELINE'
# PSCAL6  =   1.000000000000E+00
# PZERO6  =   0.000000000000E+00
# PTYPE7  = 'FREQSEL '
# PSCAL7  =   1.000000000000E+00
# PZERO7  =   0.000000000000E+00
# PTYPE8  = 'SOURCE  '
# PSCAL8  =   1.000000000000E+00
# PZERO8  =   0.000000000000E+00
# PTYPE9  = 'INTTIM  '
# PSCAL9  =   1.000000000000E+00
# PZERO9  =   0.000000000000E+00
# OBJECT  = 'MULTI   '
# DATE-OBS= '2023-12-05T23:34:03.696000'
# TELESCOP= 'ALMA    '
# INSTRUME= 'ALMA    '
# OBSERVER= 'sebamarino'
# SORTORD = 'TB      '
# SPECSYS = 'LSRK    '
# RESTFREQ=   3.457959900000E+11
# HISTORY AIPS WTSCAL = 1.0
#
# ORIGIN  = 'casacore '

# %%
lb_data['data'].shape
# Out:
# (37926, 1, 1, 1, 30, 2, 3)

# %%
lb_data['data'][:,0,0,0,:,:,2].ravel()
# Out:
# array([0.0030726 , 0.00323335, 0.0030726 , ..., 0.00426149, 0.00433125,
#        0.00426149], shape=(2275560,), dtype='>f4')

# %%
plt.hist(lb[0].data['data'][:,:,:,:,:,:,2].ravel())
plt.title("LB spw0 weights")
plt.ylabel("Count")
plt.xlabel("Weights...?")
# Out:
# Text(0.5, 0, 'Weights...?')

# %%
plt.scatter(lb_data["UU"], lb_data["VV"], marker=".")
plt.title("ARKS 49 Ceti Visibilites")
plt.xlabel("u (units??)")
plt.ylabel("v (units??)")
# Out:
# Text(0, 0.5, 'v (units??)')

# %%
CORNERS = {
    "top right": 1,
    "top left": 2,
    "bottom left": 3,
    "bottom right": 4,
    "right": 5,
    "left": 6,
    "bottom": 8,
    "top": 9,
}

def add_beam(
    ax,
    header=None,
    major=None,
    minor=None,
    angle=None,
    corner="bottom left",
    frame=False,
    borderpad=0.4,
    pad=0.5,
    **kwargs,
):
    """
    Display the beam shape and size.

    Parameters
    ----------
    ax : :class:`~astropy.visualization.wcsaxes.WCSAxes`
        WCSAxes instance in which the beam shape and size is displayed. The WCS
        must be celestial.
    header : :class:`~astropy.io.fits.Header`, optional
        Header containing the beam parameters. If specified, the ``BMAJ``,
        ``BMIN``, and ``BPA`` keywords will be searched in the FITS header
        to set the major and minor axes and the position angle on the sky.
    major : float or :class:`~astropy.units.Quantity`, optional
        Major axis of the beam in degrees or an angular quantity.
    minor : float, or :class:`~astropy.units.Quantity`, optional
        Minor axis of the beam in degrees or an angular quantity.
    angle : float or :class:`~astropy.units.Quantity`, optional
        Position angle of the beam on the sky in degrees or an angular
        quantity in the anticlockwise direction.
    corner : str, optional
        The beam location. Acceptable values are ``'left'``, ``'right'``,
        ``'top'``, 'bottom', ``'top left'``, ``'top right'``, ``'bottom left'``
        (default), and ``'bottom right'``.
    frame : bool, optional
        Whether to display a frame behind the beam (default is ``False``).
    borderpad : float, optional
        Border padding, in fraction of the font size. Default is 0.4.
    pad : float, optional
        Padding around the beam, in fraction of the font size. Default is 0.5.
    kwargs
        Additional arguments are passed to :class:`matplotlib.patches.Ellipse`.

    Notes
    -----
    This function may be inaccurate when:

    - The pixel scales at the reference pixel are different from the pixel scales
      within the image extent (e.g., when the reference pixel is well outside of
      the image extent and the projection is non-linear)
    - The pixel scales in the two directions are very different from each other
      (e.g., rectangular pixels)

    """
    if header and major:
        raise ValueError(
            "Either header or major/minor/angle must be specified, not both."
        )

    if header:
        major = header["BMAJ"]
        minor = header["BMIN"]
        angle = header["BPA"]

    if isinstance(major, u.Quantity):
        major = major.to(u.degree).value

    if isinstance(minor, u.Quantity):
        minor = minor.to(u.degree).value

    if isinstance(angle, u.Quantity):
        angle = angle.to(u.degree).value


    pix_scale = proj_plane_pixel_scales(ax.wcs)
    sx = pix_scale[0]
    sy = pix_scale[1]
    degrees_per_pixel = np.sqrt(sx * sy)
    #else:
        #raise ValueError("Cannot show beam when WCS is not celestial")

    minor /= degrees_per_pixel
    major /= degrees_per_pixel

    aux_tr_box = AuxTransformBox(ax.transData)
    ellipse = Ellipse((0, 0), width=minor, height=major, angle=angle, **kwargs)
    aux_tr_box.add_artist(ellipse)
    box = AnchoredOffsetbox(
        child=aux_tr_box,
        pad=pad,
        borderpad=borderpad,
        loc=CORNERS[corner],
        frameon=frame,
    )
    ax.add_artist(box)

# %%
plt.style.use('default')
plt.rcParams.update({'font.size': 10})

# %%
bunit_add = fits.open("inc_23warp_21_wpa179.5_hanning.fits", mode="update")
bunit_add["PRIMARY"].header["BUNIT"] = 'Jy'
bunit_add.flush()
bunit_add.close()

# %%
path = 'inc_23warp_21_wpa179.5_hanning.fits'
data, velax = bm.load_cube(path)
rms = bm.estimate_RMS(data=data, N=1)
m0 = bm.collapse_zeroth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=m0, method='zeroth', path=path)

# %%
path = 'inc_23.0warp_21.0_wpa179.5.fits'
data, velax = bm.load_cube(path)
rms = bm.estimate_RMS(data=data, N=1)
m0 = bm.collapse_zeroth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=m0, method='zeroth', path=path)

# %%
inc23nowarpm0 = fits.open('inc_23.0warp_0.0_wpa0.0_M0.fits')
inc23nowarpm0_data = inc23nowarpm0["PRIMARY"].data

inc23warpm0 = fits.open('inc_23.0warp_5.25_wpa179.5_M0.fits')
inc23warpm0_data = inc23warpm0["PRIMARY"].data

# %%
warpext = fits.open('inc_23.0warp_21.0_wpa179.5_M0.fits')
warpext_data = warpext["PRIMARY"].data

# %%
512*0.05
# Out:
# 25.6

# %%
fig, ax = plt.subplots()
plt.imshow(inc23nowarpm0_data, vmin=0, vmax=2, extent=[0,25.6,0,25.6])
plt.colorbar(label="Jy km/s")
ax.set_xlabel("arcsec")
ax.set_ylabel("arcsec")
fig.set_size_inches(5.75, 5)
plt.savefig("m0nowarp.png")
#plt.xlabel()

# %%
fig, ax = plt.subplots()
plt.imshow(inc23warpm0_data, vmin=-.01, vmax=2, extent=[0,25.6,0,25.6])
plt.colorbar(label="Jy km/s")
ax.set_xlabel("arcsec")
ax.set_ylabel("arcsec")
plt.savefig("m0warp.png")
#plt.xlabel()

# %%
fig, ax = plt.subplots()
plt.imshow(warpext_data, vmin=-.01, vmax=2, extent=[0,25.6,0,25.6])
plt.colorbar(label="Jy km/s")
fig.set_size_inches(5.75, 5)
ax.set_xlabel("arcsec")
ax.set_ylabel("arcsec")
plt.savefig("m0warp.png")
#plt.xlabel()

# %%
path = '12CO_LSRK_cleanimage.fits'
data, velax = bm.load_cube(path)
rms = bm.estimate_RMS(data=data, N=1)
m0 = bm.collapse_zeroth(velax=velax, data=data, rms=rms)
bm.save_to_FITS(moments=m0, method='zeroth', path=path)

# %%
datam0 = fits.open('12CO_LSRK_cleanimage_M0.fits')
datam0_data = datam0[0].data
datam0_header = datam0[0].header

# %%
wcs_ceti = WCS(datam0_header)

# %%
wcs_ceti
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---SIN' 'DEC--SIN'
# CRVAL : 23.65808076667 -15.676379615
# CRPIX : 513.0 513.0
# PC1_1 PC1_2  : 1.0 0.0
# PC2_1 PC2_2  : 0.0 1.0
# CDELT : -4.444444444444e-06 4.444444444444e-06
# NAXIS : 1024  1024

# %%
fig, ax = plt.subplots()
plt.imshow(datam0_data, origin="lower", cmap="cividis", aspect="equal")
#plt.imshow( , vmin=0, vmax=170)
ax = plt.subplot(projection=wcs_ceti)
overlay = ax.get_coords_overlay("icrs")
plt.xlabel(r"RA")
plt.ylabel(r"Dec")
#plt.colorbar(label="Jy m/s")
#fig.set_size_inches(5.75, 5)
#ax.set_ylim(300,700)
#ax.set_xlim(300,700)
#ax.set_xlabel("arcsec")
#ax.set_ylabel("arcsec")
#plt.savefig("m0warp.png")

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection=wcs_ceti))
plt.imshow(datam0_data, origin='lower')
ax.set_ylim(275,725)
ax.set_xlim(275,725)
plt.colorbar(label='Jy/beam m/s')
plt.xlabel(r"RA")
plt.ylabel(r"Dec")
fig.set_size_inches(5, 5)
add_beam(ax, header=datam0_header, corner='bottom left', frame=False, fill=False,hatch='//////', color="white")

# %%
path = '12CO_LSRK_cleanimage.fits'
data, velax = bm.load_cube(path)
rms = bm.estimate_RMS(data=data, N=1)
threshold_mask = bm.get_threshold_mask(data=data,
                                       clip=4,
                                       smooth_threshold_mask=0.0)
masked_data = data*threshold_mask
m1 = bm.collapse_first(velax=velax, data=masked_data, rms=rms)
bm.save_to_FITS(moments=m1, method='first', path=path)

# %%
datam1 = fits.open('12CO_LSRK_cleanimage_M1.fits')
datam1_data = datam1[0].data
datam1_header = datam1[0].header

# %%
fig, ax = plt.subplots(subplot_kw=dict(projection=wcs_ceti))
color_map = cmc.vik
plt.imshow(datam1_data-2780, origin='lower', cmap=color_map, vmin=-6000, vmax=6000)
ax.set_ylim(295,705)
ax.set_xlim(290,710)
plt.colorbar(label='Jy/beam m/s')
plt.xlabel(r"RA")
plt.ylabel(r"Dec")
fig.set_size_inches(5, 5)
add_beam(ax, header=datam0_header, corner='bottom left', frame=False, fill=False,hatch='//////', color="grey")

# %%
ax
# Out:
# <WCSAxes: >

# %%
.16*800
# Out:
# 128.0

# %%
datam0_header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1024
# NAXIS2  =                 1024
# BMAJ    = 6.74637738201353E-05
# BMIN    = 6.02541863918304E-05
# BPA     =    88.17740631103516
# BUNIT   = 'Jy/beam m/s'
# CTYPE1  = 'RA---SIN'
# CRVAL1  =       23.65808076667
# CDELT1  =  -4.444444444444E-06
# CRPIX1  =                513.0
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =        -15.676379615
# CDELT2  =   4.444444444444E-06
# CRPIX2  =                513.0
# CUNIT2  = 'deg     '
# RESTFRQ =       345795989900.0
# SPECSYS = 'LSRK    '
# COMMENT made with bettermoments

# %%
resid_m0 = fits.open('resid_m0_nosigma.fits')
resid_m0_data = resid_m0[0].data
resid_m0_header = resid_m0[0].header

# %%
resid_m0_header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                   70
# NAXIS2  =                   70
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.675649722318E-04
# BMIN    =   1.154586725963E-04
# BPA     =   8.903882598877E+01
# BTYPE   = 'Intensity'
# OBJECT  = '        '
# BUNIT   = 'Jy/beam.km/s'       /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -1.567637259295E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.365779056704E+01
# CDELT1  =  -2.777777948778E-05
# CRPIX1  =   3.600000000000E+01
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =  -1.567637259295E+01
# CDELT2  =   2.777777948778E-05
# CRPIX2  =   3.600000000000E+01
# CUNIT2  = 'deg     '
# CTYPE3  = 'VRAD    '
# CRVAL3  =  -4.070800096788E+03
# CDELT3  =   2.645953325818E+02
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'm/s     '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   3.457959802202E+11 /Rest Frequency (Hz)
# SPECSYS = 'TOPOCENT'           /Spectral reference frame
# ALTRVAL =   3.458006756896E+11 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  259 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# DATE-OBS= '2013-11-04T04:21:39.274975'
# TIMESYS = 'UTC     '
# OBSGEO-X=   2.225142180269E+06
# OBSGEO-Y=  -5.440307370349E+06
# OBSGEO-Z=  -2.481029851874E+06
# DATE    = '2026-01-01T04:36:17.060599' /Date FITS file was written
# ORIGIN  = 'CASA 6.6.5-31 CASAtools:v1.0.0'
# HISTORY CASA START LOGTABLE
# HISTORY 2026-01-01T04:33:23 INFO SRCCODE='::immoments'
# HISTORY version: 6.6.5-31 CASAtools:v1.0.0
# HISTORY 2026-01-01T04:33:23 INFO SRCCODE='::immoments'
# HISTORY immoments(imagename="resid.cm", moments=[0], axis=2, region="", box="",
# HISTORY > chans="", stokes="", mask="", includepix=-1, excludepix=-1, outfile="r
# HISTORY >sid_m0.im", stretch=False)
# HISTORY CASA END LOGTABLE

# %%
wcs_resid = WCS(resid_m0_header)

# %%
wcs_resid
# Out:
# WCS Keywords
#
# Number of WCS axes: 4
# CTYPE : 'RA---SIN' 'DEC--SIN' 'VRAD' 'STOKES'
# CRVAL : 23.65779056704 -15.67637259295 -4070.800096788 1.0
# CRPIX : 36.0 36.0 1.0 1.0
# PC1_1 PC1_2 PC1_3 PC1_4  : 1.0 0.0 0.0 0.0
# PC2_1 PC2_2 PC2_3 PC2_4  : 0.0 1.0 0.0 0.0
# PC3_1 PC3_2 PC3_3 PC3_4  : 0.0 0.0 1.0 0.0
# PC4_1 PC4_2 PC4_3 PC4_4  : 0.0 0.0 0.0 1.0
# CDELT : -2.777777948778e-05 2.777777948778e-05 264.5953325818 1.0
# NAXIS : 70  70  1  1

# %%
resid_m0_header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                   70
# NAXIS2  =                   70
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.675649722318E-04
# BMIN    =   1.154586725963E-04
# BPA     =   8.903882598877E+01
# BTYPE   = 'Intensity'
# OBJECT  = '        '
# BUNIT   = 'Jy/beam.km/s'       /Brightness (pixel) unit
# EQUINOX =   2.000000000000E+03
# RADESYS = 'FK5     '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -1.567637259295E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.365779056704E+01
# CDELT1  =  -2.777777948778E-05
# CRPIX1  =   3.600000000000E+01
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =  -1.567637259295E+01
# CDELT2  =   2.777777948778E-05
# CRPIX2  =   3.600000000000E+01
# CUNIT2  = 'deg     '
# CTYPE3  = 'VRAD    '
# CRVAL3  =  -4.070800096788E+03
# CDELT3  =   2.645953325818E+02
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'm/s     '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   3.457959802202E+11 /Rest Frequency (Hz)
# SPECSYS = 'TOPOCENT'           /Spectral reference frame
# ALTRVAL =   3.458006756896E+11 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  259 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# DATE-OBS= '2013-11-04T04:21:39.274975'
# TIMESYS = 'UTC     '
# OBSGEO-X=   2.225142180269E+06
# OBSGEO-Y=  -5.440307370349E+06
# OBSGEO-Z=  -2.481029851874E+06
# DATE    = '2026-01-01T04:36:17.060599' /Date FITS file was written
# ORIGIN  = 'CASA 6.6.5-31 CASAtools:v1.0.0'
# HISTORY CASA START LOGTABLE
# HISTORY 2026-01-01T04:33:23 INFO SRCCODE='::immoments'
# HISTORY version: 6.6.5-31 CASAtools:v1.0.0
# HISTORY 2026-01-01T04:33:23 INFO SRCCODE='::immoments'
# HISTORY immoments(imagename="resid.cm", moments=[0], axis=2, region="", box="",
# HISTORY > chans="", stokes="", mask="", includepix=-1, excludepix=-1, outfile="r
# HISTORY >sid_m0.im", stretch=False)
# HISTORY CASA END LOGTABLE

# %%
# Plot beam
import math
xoff=3
yoff=3
t=np.arange(0.0,2.0*np.pi,0.05)
x=resid_m0_header['bmaj']*1800.0*np.cos(t)*np.cos((resid_m0_header['bpa']+90.0)*math.pi/180.0)-1800.0*resid_m0_header['bmin']*np.sin(t)*np.sin((resid_m0_header['bpa']+90.0)*math.pi/180.0)+xoff
y=1800.0*resid_m0_header['bmaj']*np.cos(t)*np.sin((resid_m0_header['bpa']+90.0)*math.pi/180.0)+1800.0*resid_m0_header['bmin']*np.sin(t)*np.cos((resid_m0_header['bpa']+90.0)*math.pi/180.0)+yoff

# %%
resid_m0.header
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 resid_m0.header
#
# AttributeError: 'HDUList' object has no attribute 'header'

# %%
1/3600
# Out:
# 0.0002777777777777778

# %%
ax.wcs
# Out:
# <astropy.wcs.wcsapi.fitswcs.SlicedFITSWCS object at 0x7f79a5869d30>
# SlicedFITSWCS Transformation
#
# This transformation has 2 pixel and 2 world dimensions
#
# Array shape (Numpy order): (70, 70)
#
# Pixel Dim  Axis Name  Data size  Bounds
#         0  None              70  None
#         1  None              70  None
#
# World Dim  Axis Name  Physical Type  Units
#         0  None       pos.eq.ra      deg
#         1  None       pos.eq.dec     deg
#
# Correlation between pixel and world axes:
#
#            Pixel Dim
# World Dim    0    1
#         0  yes  yes
#         1  yes  yes

# %%
proj_plane_pixel_scales(wcs_ceti)
# Out:
# array([4.44444444e-06, 4.44444444e-06])

# %%
ax.transData

# %%
wcs_resid.transData
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 wcs_resid.transData
#
# AttributeError: 'WCS' object has no attribute 'transData'

# %%
proj_plane_pixel_scales(wcs_resid)
# Out:
# array([2.77777795e-05, 2.77777795e-05, 2.64595333e+02, 1.00000000e+00])

# %%
CORNERS = {
    "top right": 1,
    "top left": 2,
    "bottom left": 3,
    "bottom right": 4,
    "right": 5,
    "left": 6,
    "bottom": 8,
    "top": 9,
}

def add_beam(
    ax,
    wcshead,
    header=None,
    major=None,
    minor=None,
    angle=None,
    corner="bottom left",
    frame=False,
    borderpad=0.4,
    pad=0.5,
    **kwargs,
):
    """
    Display the beam shape and size.

    Parameters
    ----------
    ax : :class:`~astropy.visualization.wcsaxes.WCSAxes`
        WCSAxes instance in which the beam shape and size is displayed. The WCS
        must be celestial.
    header : :class:`~astropy.io.fits.Header`, optional
        Header containing the beam parameters. If specified, the ``BMAJ``,
        ``BMIN``, and ``BPA`` keywords will be searched in the FITS header
        to set the major and minor axes and the position angle on the sky.
    major : float or :class:`~astropy.units.Quantity`, optional
        Major axis of the beam in degrees or an angular quantity.
    minor : float, or :class:`~astropy.units.Quantity`, optional
        Minor axis of the beam in degrees or an angular quantity.
    angle : float or :class:`~astropy.units.Quantity`, optional
        Position angle of the beam on the sky in degrees or an angular
        quantity in the anticlockwise direction.
    corner : str, optional
        The beam location. Acceptable values are ``'left'``, ``'right'``,
        ``'top'``, 'bottom', ``'top left'``, ``'top right'``, ``'bottom left'``
        (default), and ``'bottom right'``.
    frame : bool, optional
        Whether to display a frame behind the beam (default is ``False``).
    borderpad : float, optional
        Border padding, in fraction of the font size. Default is 0.4.
    pad : float, optional
        Padding around the beam, in fraction of the font size. Default is 0.5.
    kwargs
        Additional arguments are passed to :class:`matplotlib.patches.Ellipse`.

    Notes
    -----
    This function may be inaccurate when:

    - The pixel scales at the reference pixel are different from the pixel scales
      within the image extent (e.g., when the reference pixel is well outside of
      the image extent and the projection is non-linear)
    - The pixel scales in the two directions are very different from each other
      (e.g., rectangular pixels)

    """
    if header and major:
        raise ValueError(
            "Either header or major/minor/angle must be specified, not both."
        )

    if header:
        major = header["BMAJ"]
        minor = header["BMIN"]
        angle = header["BPA"]

    if isinstance(major, u.Quantity):
        major = major.to(u.degree).value

    if isinstance(minor, u.Quantity):
        minor = minor.to(u.degree).value

    if isinstance(angle, u.Quantity):
        angle = angle.to(u.degree).value


    pix_scale = proj_plane_pixel_scales(wcshead)
    sx = pix_scale[0]
    sy = pix_scale[1]
    degrees_per_pixel = np.sqrt(sx * sy)
    #else:
        #raise ValueError("Cannot show beam when WCS is not celestial")

    minor /= degrees_per_pixel
    major /= degrees_per_pixel

    aux_tr_box = AuxTransformBox(ax.transData)
    ellipse = Ellipse((0, 0), width=minor, height=major, angle=angle, **kwargs)
    aux_tr_box.add_artist(ellipse)
    box = AnchoredOffsetbox(
        child=aux_tr_box,
        pad=pad,
        borderpad=borderpad,
        loc=CORNERS[corner],
        frameon=frame,
    )
    ax.add_artist(box)

# %%
#fig, ax = plt.subplots(subplot_kw=dict(projection=wcs_ceti))

fig, ax = plt.subplots(subplot_kw=dict(projection=wcs_resid[:,:,0,0]))
plt.imshow(resid_m0_data[0,0,:,:], origin='lower', cmap="magma", vmin=-0.11, vmax=0.11)
plt.colorbar(label='Jy/beam km/s')
plt.title("Residual Data (Hughes et al. 2017)")
plt.xlabel(r"RA")
plt.ylabel(r"Dec")
plt.fill(x,y,fill=False,hatch='//////')
#plt.plot(x,y)
fig.set_size_inches(7, 5)
add_beam(ax, wcshead=wcs_resid header=resid_m0_header, corner='bottom left', frame=False, fill=False,hatch='//////', color="white")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 12
#      10 #plt.plot(x,y)
#      11 fig.set_size_inches(7, 5)
# ---> 12 add_beam(ax, header=resid_m0_header, corner='bottom left', frame=False, fill=False,hatch='//////', color="white")
#
# Cell In[94], line 87, in add_beam(ax, header, major, minor, angle, corner, frame, borderpad, pad, **kwargs)
#      83 if isinstance(angle, u.Quantity):
#      84     angle = angle.to(u.degree).value
# ---> 87 pix_scale = proj_plane_pixel_scales(ax)
#      88 sx = pix_scale[0]
#      89 sy = pix_scale[1]
#
# File /opt/anaconda3/lib/python3.13/site-packages/astropy/wcs/utils.py:452, in proj_plane_pixel_scales(wcs)
#     411 def proj_plane_pixel_scales(wcs):
#     412     """
#     413     For a WCS returns pixel scales along each axis of the image pixel at
#     414     the ``CRPIX`` location once it is projected onto the
#    (...)    450
#     451     """
# --> 452     return np.sqrt((wcs.pixel_scale_matrix**2).sum(axis=0, dtype=float))
#
# AttributeError: 'WCSAxes' object has no attribute 'pixel_scale_matrix'

# %%
proj = dict(projection=wcs_resid[0,0,:,:])
wcs_resid[0,0,:,:].is_celestial = True

# %%
ax.wcs.is_celestial=True

# %%
plt.fill(x,y,fill=False,hatch='//////')

# %%
plt.imshow(resid_m0_data[0,0,:,:], origin='lower')

# %%
wcs_resid.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-98752599ee57> in <module>
# ----> 1 wcs_resid.shape
#
# AttributeError: 'WCS' object has no attribute 'shape'
